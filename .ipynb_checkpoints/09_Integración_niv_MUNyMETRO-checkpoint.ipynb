# %% [markdown]
# Código para integrar las bases de datos de manzanas y localidades en entidades municipales y/o metropolitanas. Extracción de excel de *Indicadores*.

# %%
pip install xlsxwriter
# Out:
# Collecting xlsxwriter
#   Downloading XlsxWriter-3.2.2-py3-none-any.whl.metadata (2.8 kB)
# Downloading XlsxWriter-3.2.2-py3-none-any.whl (165 kB)
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    ---------------------------------------- 0.0/165.1 kB ? eta -:--:--
#    -------------- ------------------------- 61.4/165.1 kB 3.2 MB/s eta 0:00:01
#    -------------- ------------------------- 61.4/165.1 kB 3.2 MB/s eta 0:00:01
#    -------------- ------------------------- 61.4/165.1 kB 3.2 MB/s eta 0:00:01
#    ------------------- ------------------- 81.9/165.1 kB 416.7 kB/s eta 0:00:01
#    ------------------- ------------------- 81.9/165.1 kB 416.7 kB/s eta 0:00:01
#    --------------------- ----------------- 92.2/165.1 kB 291.5 kB/s eta 0:00:01
#    --------------------- ----------------- 92.2/165.1 kB 291.5 kB/s eta 0:00:01
#    --------------------- ----------------- 92.2/165.1 kB 291.5 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ------------------------- ------------ 112.6/165.1 kB 252.2 kB/s eta 0:00:01
#    ---------------------------- --------- 122.9/165.1 kB 112.6 kB/s eta 0:00:01
#    ---------------------------- --------- 122.9/165.1 kB 112.6 kB/s eta 0:00:01
#    ---------------------------- --------- 122.9/165.1 kB 112.6 kB/s eta 0:00:01
#    ---------------------------- --------- 122.9/165.1 kB 112.6 kB/s eta 0:00:01
#    ---------------------------- --------- 122.9/165.1 kB 112.6 kB/s eta 0:00:01
#    ---------------------------- --------- 122.9/165.1 kB 112.6 kB/s eta 0:00:01
#    ---------------------------- --------- 122.9/165.1 kB 112.6 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    -------------------------------- ----- 143.4/165.1 kB 100.2 kB/s eta 0:00:01
#    --------------------------------------  163.8/165.1 kB 78.6 kB/s eta 0:00:01
#    --------------------------------------- 165.1/165.1 kB 77.4 kB/s eta 0:00:00
# Installing collected packages: xlsxwriter
# Successfully installed xlsxwriter-3.2.2
# Note: you may need to restart the kernel to use updated packages.
#   WARNING: Retrying (Retry(total=4, connect=None, read=None, redirect=None, status=None)) after connection broken by 'ConnectTimeoutError(<pip._vendor.urllib3.connection.HTTPSConnection object at 0x000002139DA1ED50>, 'Connection to files.pythonhosted.org timed out. (connect timeout=15)')': /packages/9b/07/df054f7413bdfff5e98f75056e4ed0977d0c8716424011fac2587864d1d3/XlsxWriter-3.2.2-py3-none-any.whl.metadata

# %%
import pandas as pd
import geopandas as gpd
import numpy as np
from shapely.geometry import Polygon
from dbfread import DBF
import jenkspy
import json
from jenkspy import jenks_breaks
import openpyxl
from openpyxl.styles import Font, PatternFill

# %% [markdown]
# # Desde LOC

# %%
# ### RUTA MET LOC - ALEJANDRO (local)
# #ruta gpkg fin
# MAPA_TIPO_ruta = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\Loc_Tipologías_NAC.gpkg"
# # Leer la capa existente del GeoPackage base
# MAPA_TIPO_gdf = gpd.read_file(MAPA_TIPO_ruta, layer='Loc_SubTipologias_ue')

### RUTA MZN EQ - ALEJANDRO (SSD)
#ruta gpkg fin
MAPA_TIPO_ruta  = r"Z:\VOCES\DATA\Tratados\NAC\INT_LOC_NAC\Loc_Tipologías_NAC.gpkg"
# Leer la capa existente del GeoPackage base
MAPA_TIPO_gdf = gpd.read_file(MAPA_TIPO_ruta, layer='Mzn_SubTipologias_eq')

# %% [markdown]
# ## Sumatoria y re-cálculo de indicadores

# %% [markdown]
# ### Resultados por Metrópoli

# %%
# # rutas excel - Alejandro (local) 
# excel_path = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\resultados_metropoli.xlsx"
# excel_path_2 = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\estadísticas_bruto_metropoli.xlsx")

# rutas excel - Alejandro (SSD) 
excel_path = r"Z:\VOCES\DATA\Tratados\NAC\INT_LOC_NAC\resultados_metropoli.xlsx"
excel_path_2 = r"Z:\VOCES\DATA\Tratados\NAC\INT_LOC_NAC\estadísticas_bruto_metropoli.xlsx"

# %%
# Filtrar polígonos por categoría 'Urbana' y 'Rural' con CALIF_CLAS diferente de '0'
MAPA_TIPO_urbana = MAPA_TIPO_gdf[MAPA_TIPO_gdf['AMBITO'] == 'Urbana']
MAPA_TIPO_rural = MAPA_TIPO_gdf[(MAPA_TIPO_gdf['AMBITO'] == 'Rural') & (MAPA_TIPO_gdf['CALIF_CLAS'] != '0')]

# Concatenar los GeoDataFrames filtrados
MAPA_TIPO_filtrado = pd.concat([MAPA_TIPO_urbana, MAPA_TIPO_rural])

# Columnas que se sumarán
columnas_a_sumar = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 
    'TVIVHAB2010', 'TVIVHAB2020', 'TVIVPAR2010', 'TVIVPAR2020',
    'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010', 'VIVPAR_HAB2020',
    'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
    'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 
    'VIV2C2010', 'VIV2C2020', 'VIV3C2010', 'VIV3C2020', 'area_ha',
    'UE_20', 'Emp_20', 'UE_10', 'Emp_10',
    'num_edu', 'num_sal', 'num_rec', 'num_ser']

# Sumar las columnas y agrupar por 'NOM_MET' y 'TIPO_MET'
MAPA_TIPO_sumado = MAPA_TIPO_filtrado.groupby(['CVE_MET','NOM_MET', 'TIPO_MET'])[columnas_a_sumar].sum(numeric_only=True).reset_index()

# Contar las localidades agrupadas
MAPA_TIPO_sumado['Localidades'] = MAPA_TIPO_filtrado.groupby(['NOM_MET', 'TIPO_MET']).size().values

# Recalcular los campos
MAPA_TIPO_sumado['DIFPOP'] = MAPA_TIPO_sumado['POPTOT2020'] - MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['DIFVIV'] = MAPA_TIPO_sumado['VIVTOT2020'] - MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['RELPOP'] = MAPA_TIPO_sumado['DIFPOP'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['RELVIV'] = MAPA_TIPO_sumado['DIFVIV'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['CVEPOP'] = np.where(MAPA_TIPO_sumado['RELPOP'] < -0.000000001, 'A', 'B')
MAPA_TIPO_sumado['CVEVIV'] = np.where(MAPA_TIPO_sumado['RELVIV'] < -.0703, '1',
                                      np.where((MAPA_TIPO_sumado['RELVIV'] >= -.0703) & (MAPA_TIPO_sumado['RELVIV'] <= .0703), 
                                               '2', '3'))
MAPA_TIPO_sumado['CVE'] = MAPA_TIPO_sumado['CVEPOP'] + MAPA_TIPO_sumado['CVEVIV'].astype(str)

conditions = [
    (MAPA_TIPO_sumado['POPTOT2020'] == 0),
    (MAPA_TIPO_sumado['POPTOT2010'] == 0) & (MAPA_TIPO_sumado['VIVTOT2010'] == 0) & (MAPA_TIPO_sumado['CVE'] == 'B3')
]
choices = ['DH', 'B3\'']
MAPA_TIPO_sumado['TIPOLOGIA'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE'])

MAPA_TIPO_sumado['DENS_POP10'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_POP20'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSPOP'] = MAPA_TIPO_sumado['DENS_POP20'] - MAPA_TIPO_sumado['DENS_POP10']

MAPA_TIPO_sumado['DENS_VIV10'] = MAPA_TIPO_sumado['VIVTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_VIV20'] = MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSVIV'] = MAPA_TIPO_sumado['DENS_VIV20'] - MAPA_TIPO_sumado['DENS_VIV10']

MAPA_TIPO_sumado['CUARTOS2010'] = ((MAPA_TIPO_sumado['VIV1C2010'] * 1) + (MAPA_TIPO_sumado['VIV2C2010'] * 2) + (MAPA_TIPO_sumado['VIV3C2010'] * 4))
MAPA_TIPO_sumado['CUARTOS2020'] = ((MAPA_TIPO_sumado['VIV1C2020'] * 1) + (MAPA_TIPO_sumado['VIV2C2020'] * 2) + (MAPA_TIPO_sumado['VIV3C2020'] * 4))

MAPA_TIPO_sumado['CPERC2010'] = MAPA_TIPO_sumado['CUARTOS2010'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['CPERC2020'] = MAPA_TIPO_sumado['CUARTOS2020'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_CPERC'] = MAPA_TIPO_sumado['CPERC2020'] - MAPA_TIPO_sumado['CPERC2010']

MAPA_TIPO_sumado['HABXVIV2010'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['HABXVIV2020'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_HABXVIV'] = MAPA_TIPO_sumado['HABXVIV2020'] - MAPA_TIPO_sumado['HABXVIV2010']


MAPA_TIPO_sumado['DESHABITACION_2010'] = MAPA_TIPO_sumado['VIVPAR_DES2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['DESHABITACION_2020'] = MAPA_TIPO_sumado['VIVPAR_DES2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_DESHAB'] = MAPA_TIPO_sumado['DESHABITACION_2020'] - MAPA_TIPO_sumado['DESHABITACION_2010']

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_POP'] = (((MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['POPTOT2010']) ** (1/10)) - 1) * 100
MAPA_TIPO_sumado['TASA_VIV'] = (((MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['VIVTOT2010']) ** (1/10)) - 1) * 100

def asignar_subtipologia_2010(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2010'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado

    
def asignar_subtipologia_2020(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2020'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado


# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2010'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2010, axis=1)

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2020'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2020, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA'] = MAPA_TIPO_sumado['TIPOLOGIA'].astype(str) + '-' + MAPA_TIPO_sumado['R_DESHAB_2020'].astype(str)

############################################indicadores DENUE

#Tamaño de unidades promedio: Empleados entre UE por manzana
MAPA_TIPO_sumado['TAMAÑO'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['UE_20']

# Calcular las sumas de POPTOT2020 y POPTOT2010 por CVE_MET
sum_emptot2020 = MAPA_TIPO_sumado.groupby('CVE_MET')['Emp_20'].transform('sum')
sum_emptot2010 = MAPA_TIPO_sumado.groupby('CVE_MET')['Emp_10'].transform('sum')

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_EMP_MET'] = (((sum_emptot2020 / sum_emptot2010) ** (1/10)) - 1) * 100

#resto de campos
MAPA_TIPO_sumado['DIF_EMP'] = MAPA_TIPO_sumado['Emp_20'] - MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['DIF_UEC'] = MAPA_TIPO_sumado['UE_20'] - MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['REL_EMP'] = MAPA_TIPO_sumado['DIF_EMP'] / MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['REL_UEC'] = MAPA_TIPO_sumado['DIF_UEC'] / MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['CVE_EMP'] = np.where(MAPA_TIPO_sumado['REL_EMP'] < -0.000000001, '1', '2')
MAPA_TIPO_sumado['CVE_UEC'] = np.where(MAPA_TIPO_sumado['REL_UEC'] < -.1, 'A',
                                   np.where((MAPA_TIPO_sumado['REL_UEC'] >= -.1) & (MAPA_TIPO_sumado['REL_UEC'] <= .1), 
                                            'B', 'C'))
MAPA_TIPO_sumado['CVE_ue'] = MAPA_TIPO_sumado['CVE_UEC'].astype(str) + MAPA_TIPO_sumado['CVE_EMP']
conditions = [
    (MAPA_TIPO_sumado['Emp_20'] == 0),
    (MAPA_TIPO_sumado['Emp_10'] == 0) & (MAPA_TIPO_sumado['UE_10'] == 0) & (MAPA_TIPO_sumado['CVE_ue'] == 'C2')
]
choices = ['00', 'C2+']
MAPA_TIPO_sumado['TIPOLOGIA_ue'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE_ue'])

MAPA_TIPO_sumado['DENS_EMP20'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_EMP10'] = MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['DENS_UEC20'] = MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_UEC10'] = MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['EPERC2010'] = (MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['POPTOT2010'])*100
MAPA_TIPO_sumado['EPERC2020'] = (MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['POPTOT2020'])*100
MAPA_TIPO_sumado['DIF_EPERC'] = MAPA_TIPO_sumado['EPERC2020'] - MAPA_TIPO_sumado['EPERC2010']

MAPA_TIPO_sumado['UEPERC2010'] = (MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['POPTOT2010'])*100
MAPA_TIPO_sumado['UEPERC2020'] = (MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['POPTOT2020'])*100
MAPA_TIPO_sumado['DIF_UEPERC'] = MAPA_TIPO_sumado['UEPERC2020'] - MAPA_TIPO_sumado['UEPERC2010']


def asignar_subtipologia(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, 1, 30, 100]  # Modifica estos valores según tus necesidades
    
# Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[1]:
        return 'SUE'
    elif rangos_deshabitacion_grupo[1] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[2]:
        return 'MICRO'
    elif rangos_deshabitacion_grupo[2] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[3]:
        return 'MEDIANA'
    elif row['TAMAÑO'] >= rangos_deshabitacion_grupo[3]:
        return 'GRANDE'
    else:
        return '0'  # Valor predeterminado

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_TAM'] = MAPA_TIPO_sumado.apply(asignar_subtipologia, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA_ue'] = MAPA_TIPO_sumado['TIPOLOGIA_ue'].astype(str) + '-' + MAPA_TIPO_sumado['R_TAM'].astype(str)

###################################################################

MAPA_TIPO_sumado['NUM_EQ'] = MAPA_TIPO_sumado['num_edu'] + MAPA_TIPO_sumado['num_sal'] + MAPA_TIPO_sumado['num_rec'] + MAPA_TIPO_sumado['num_ser']

MAPA_TIPO_sumado['EQPERC2020'] = (MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['POPTOT2020'])*1000

# Crear el campo Densidad de Equipamientos
MAPA_TIPO_sumado['DENS_EQ'] = MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['area_ha']

###################################################################

# Redondear a 3 decimales
MAPA_TIPO_sumado = MAPA_TIPO_sumado.round(3)

# Guardar los datos en un archivo Excel

MAPA_TIPO_sumado.to_excel(excel_path, index=False)

# Leer el archivo Excel
wb = openpyxl.load_workbook(excel_path)

# Seleccionar la hoja de cálculo
sheet = wb.active

# Ajustar el ancho de las columnas automáticamente
for col in sheet.columns:
    max_length = 0
    column = col[0].column_letter
    for cell in col:
        try:
            if len(str(cell.value)) > max_length:
                max_length = len(cell.value)
        except:
            pass
    adjusted_width = (max_length + 2) * 1.2
    sheet.column_dimensions[column].width = adjusted_width

# Aplicar color rojo a las celdas negativas en columnas con prefijo 'DIF_'
red_font = Font(color="FF0000")

for col in sheet.iter_cols(min_row=2, min_col=1, max_col=sheet.max_column):
    col_name = sheet.cell(row=1, column=col[0].column).value
    if col_name.startswith('DIF_'):
        for cell in col:
            if isinstance(cell.value, (int, float)) and cell.value < 0:
                cell.font = red_font

# Guardar los cambios en el archivo Excel
wb.save(excel_path_2)

# %% [markdown]
# ### Resultados por Municipio

# %%
# # rutas excel - Gerardo
# excel_path = 'C:/Users/ADMIN/Desktop/Ejercicio/Localidad/resultados_municipio.xlsx'
# excel_path_2 = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\estadísticas_bruto_metropoli.xlsx")

# # rutas excel - Alejandro (local) 
# excel_path = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\resultados_municipio.xlsx"
# excel_path_2 = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\estadísticas_bruto_municipio.xlsx")

# rutas excel - Alejandro (SSD) 
excel_path = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\resultados_municipio.xlsx"
excel_path_2 = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\estadísticas_bruto_municipio.xlsx"

# %%
import pandas as pd
import numpy as np
import openpyxl
from openpyxl.styles import Font, PatternFill

# Filtrar polígonos por categoría 'Urbana' y 'Rural' con CALIF_CLAS diferente de '0'
MAPA_TIPO_urbana = MAPA_TIPO_gdf[MAPA_TIPO_gdf['AMBITO'] == 'Urbana']
MAPA_TIPO_rural = MAPA_TIPO_gdf[(MAPA_TIPO_gdf['AMBITO'] == 'Rural') & (MAPA_TIPO_gdf['CALIF_CLAS'] != '0')]

# Concatenar los GeoDataFrames filtrados
MAPA_TIPO_filtrado = pd.concat([MAPA_TIPO_urbana, MAPA_TIPO_rural])

# Columnas que se sumarán
columnas_a_sumar = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 
    'TVIVHAB2010', 'TVIVHAB2020', 'TVIVPAR2010', 'TVIVPAR2020',
    'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010', 'VIVPAR_HAB2020',
    'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
    'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 
    'VIV2C2010', 'VIV2C2020', 'VIV3C2010', 'VIV3C2020', 'area_ha',
    'UE_20', 'Emp_20', 'UE_10', 'Emp_10',
    'num_edu', 'num_sal', 'num_rec', 'num_ser']

# Sumar las columnas y agrupar por 'NOM_MET'
MAPA_TIPO_sumado = MAPA_TIPO_filtrado.groupby(['CVE_MET','CVEMUN','NOM_MET', 'TIPO_MET','TIPO_MUN'])[columnas_a_sumar].sum(numeric_only=True).reset_index()

# Contar las manzanas agrupadas
MAPA_TIPO_sumado['Localidades'] = MAPA_TIPO_filtrado.groupby(['CVEMUN', 'NOM_MET', 'TIPO_MET','TIPO_MUN']).size().values



# # Intentar cargar el archivo CSV con diferentes codificaciones y asegurar que las columnas sean string
# try:
#     agem_df = pd.read_csv("C:/Users/ADMIN/Downloads/AGEM.csv", usecols=['CVEMUN', 'NOM_MUN'], dtype=str, encoding='latin1')
# except UnicodeDecodeError:
#     agem_df = pd.read_csv("C:/Users/ADMIN/Downloads/AGEM.csv", usecols=['CVEMUN', 'NOM_MUN'], dtype=str, encoding='iso-8859-1')

# # Hacer el join con el archivo CSV basado en 'CVEMUN'
# MAPA_TIPO_sumado = pd.merge(MAPA_TIPO_sumado, agem_df, on='CVEMUN', how='left')


# Recalcular los campos
MAPA_TIPO_sumado['DIFPOP'] = MAPA_TIPO_sumado['POPTOT2020'] - MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['DIFVIV'] = MAPA_TIPO_sumado['VIVTOT2020'] - MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['RELPOP'] = MAPA_TIPO_sumado['DIFPOP'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['RELVIV'] = MAPA_TIPO_sumado['DIFVIV'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['CVEPOP'] = np.where(MAPA_TIPO_sumado['RELPOP'] < -0.000000001, 'A', 'B')
MAPA_TIPO_sumado['CVEVIV'] = np.where(MAPA_TIPO_sumado['RELVIV'] < -.0703, '1',
                                      np.where((MAPA_TIPO_sumado['RELVIV'] >= -.0703) & (MAPA_TIPO_sumado['RELVIV'] <= .0703), 
                                               '2', '3'))
MAPA_TIPO_sumado['CVE'] = MAPA_TIPO_sumado['CVEPOP'] + MAPA_TIPO_sumado['CVEVIV'].astype(str)

conditions = [
    (MAPA_TIPO_sumado['POPTOT2020'] == 0),
    (MAPA_TIPO_sumado['POPTOT2010'] == 0) & (MAPA_TIPO_sumado['VIVTOT2010'] == 0) & (MAPA_TIPO_sumado['CVE'] == 'B3')
]
choices = ['DH', 'B3\'']
MAPA_TIPO_sumado['TIPOLOGIA'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE'])

MAPA_TIPO_sumado['DENS_POP10'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_POP20'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSPOP'] = MAPA_TIPO_sumado['DENS_POP20'] - MAPA_TIPO_sumado['DENS_POP10']

MAPA_TIPO_sumado['DENS_VIV10'] = MAPA_TIPO_sumado['VIVTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_VIV20'] = MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSVIV'] = MAPA_TIPO_sumado['DENS_VIV20'] - MAPA_TIPO_sumado['DENS_VIV10']

MAPA_TIPO_sumado['CUARTOS2010'] = ((MAPA_TIPO_sumado['VIV1C2010'] * 1) + (MAPA_TIPO_sumado['VIV2C2010'] * 2) + (MAPA_TIPO_sumado['VIV3C2010'] * 4))
MAPA_TIPO_sumado['CUARTOS2020'] = ((MAPA_TIPO_sumado['VIV1C2020'] * 1) + (MAPA_TIPO_sumado['VIV2C2020'] * 2) + (MAPA_TIPO_sumado['VIV3C2020'] * 4))

MAPA_TIPO_sumado['CPERC2010'] = MAPA_TIPO_sumado['CUARTOS2010'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['CPERC2020'] = MAPA_TIPO_sumado['CUARTOS2020'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_CPERC'] = MAPA_TIPO_sumado['CPERC2020'] - MAPA_TIPO_sumado['CPERC2010']

MAPA_TIPO_sumado['HABXVIV2010'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['HABXVIV2020'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_HABXVIV'] = MAPA_TIPO_sumado['HABXVIV2020'] - MAPA_TIPO_sumado['HABXVIV2010']


MAPA_TIPO_sumado['DESHABITACION_2010'] = MAPA_TIPO_sumado['VIVPAR_DES2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['DESHABITACION_2020'] = MAPA_TIPO_sumado['VIVPAR_DES2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_DESHAB'] = MAPA_TIPO_sumado['DESHABITACION_2020'] - MAPA_TIPO_sumado['DESHABITACION_2010']

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_POP'] = (((MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['POPTOT2010']) ** (1/10)) - 1) * 100
MAPA_TIPO_sumado['TASA_VIV'] = (((MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['VIVTOT2010']) ** (1/10)) - 1) * 100

def asignar_subtipologia_2010(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2010'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado

    
def asignar_subtipologia_2020(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2020'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado


# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2010'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2010, axis=1)

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2020'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2020, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA'] = MAPA_TIPO_sumado['TIPOLOGIA'].astype(str) + '-' + MAPA_TIPO_sumado['R_DESHAB_2020'].astype(str)

############################################indicadores DENUE

#Tamaño de unidades promedio: Empleados entre UE por manzana
MAPA_TIPO_sumado['TAMAÑO'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['UE_20']

# Calcular las sumas de POPTOT2020 y POPTOT2010 por CVE_MET
sum_emptot2020 = MAPA_TIPO_sumado.groupby('CVEMUN')['Emp_20'].transform('sum')
sum_emptot2010 = MAPA_TIPO_sumado.groupby('CVEMUN')['Emp_10'].transform('sum')

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_EMP_MUN'] = (((sum_emptot2020 / sum_emptot2010) ** (1/10)) - 1) * 100

#resto de campos
MAPA_TIPO_sumado['DIF_EMP'] = MAPA_TIPO_sumado['Emp_20'] - MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['DIF_UEC'] = MAPA_TIPO_sumado['UE_20'] - MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['REL_EMP'] = MAPA_TIPO_sumado['DIF_EMP'] / MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['REL_UEC'] = MAPA_TIPO_sumado['DIF_UEC'] / MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['CVE_EMP'] = np.where(MAPA_TIPO_sumado['REL_EMP'] < -0.000000001, '1', '2')
MAPA_TIPO_sumado['CVE_UEC'] = np.where(MAPA_TIPO_sumado['REL_UEC'] < -.1, 'A',
                                   np.where((MAPA_TIPO_sumado['REL_UEC'] >= -.1) & (MAPA_TIPO_sumado['REL_UEC'] <= .1), 
                                            'B', 'C'))
MAPA_TIPO_sumado['CVE_ue'] = MAPA_TIPO_sumado['CVE_UEC'].astype(str) + MAPA_TIPO_sumado['CVE_EMP']
conditions = [
    (MAPA_TIPO_sumado['Emp_20'] == 0),
    (MAPA_TIPO_sumado['Emp_10'] == 0) & (MAPA_TIPO_sumado['UE_10'] == 0) & (MAPA_TIPO_sumado['CVE_ue'] == 'C2')
]
choices = ['00', 'C2+']
MAPA_TIPO_sumado['TIPOLOGIA_ue'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE_ue'])

MAPA_TIPO_sumado['DENS_EMP20'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_EMP10'] = MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['DENS_UEC20'] = MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_UEC10'] = MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['EPERC2010'] = (MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['POPTOT2010'])*100
MAPA_TIPO_sumado['EPERC2020'] = (MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['POPTOT2020'])*100
MAPA_TIPO_sumado['DIF_EPERC'] = MAPA_TIPO_sumado['EPERC2020'] - MAPA_TIPO_sumado['EPERC2010']

MAPA_TIPO_sumado['UEPERC2010'] = (MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['POPTOT2010'])*100
MAPA_TIPO_sumado['UEPERC2020'] = (MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['POPTOT2020'])*100
MAPA_TIPO_sumado['DIF_UEPERC'] = MAPA_TIPO_sumado['UEPERC2020'] - MAPA_TIPO_sumado['UEPERC2010']


def asignar_subtipologia(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, 1, 30, 100]  # Modifica estos valores según tus necesidades
    
# Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[1]:
        return 'SUE'
    elif rangos_deshabitacion_grupo[1] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[2]:
        return 'MICRO'
    elif rangos_deshabitacion_grupo[2] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[3]:
        return 'MEDIANA'
    elif row['TAMAÑO'] >= rangos_deshabitacion_grupo[3]:
        return 'GRANDE'
    else:
        return '0'  # Valor predeterminado

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_TAM'] = MAPA_TIPO_sumado.apply(asignar_subtipologia, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA_ue'] = MAPA_TIPO_sumado['TIPOLOGIA_ue'].astype(str) + '-' + MAPA_TIPO_sumado['R_TAM'].astype(str)

###################################################################

MAPA_TIPO_sumado['NUM_EQ'] = MAPA_TIPO_sumado['num_edu'] + MAPA_TIPO_sumado['num_sal'] + MAPA_TIPO_sumado['num_rec'] + MAPA_TIPO_sumado['num_ser']

MAPA_TIPO_sumado['EQPERC2020'] = (MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['POPTOT2020'])*1000

# Crear el campo Densidad de Equipamientos
MAPA_TIPO_sumado['DENS_EQ'] = MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['area_ha']

###################################################################

# Redondear a 3 decimales
MAPA_TIPO_sumado = MAPA_TIPO_sumado.round(3)

# Reordenar columnas: 'NOM_MUN', 'NOM_MET', 'TIPO_MET' al inicio y 'TIPO_MUN' al final
column_order = ['CVEMUN', 'NOM_MET', 'TIPO_MET'] + [col for col in MAPA_TIPO_sumado.columns if col not in ['CVEMUN', 'NOM_MET', 'TIPO_MET', 'TIPO_MUN']] + ['TIPO_MUN']
MAPA_TIPO_sumado = MAPA_TIPO_sumado[column_order]

# Guardar los datos en un archivo Excel

MAPA_TIPO_sumado.to_excel(excel_path, index=False)

# Leer el archivo Excel
wb = openpyxl.load_workbook(excel_path)

# Seleccionar la hoja de cálculo
sheet = wb.active

# Ajustar el ancho de las columnas automáticamente
for col in sheet.columns:
    max_length = 0
    column = col[0].column_letter
    for cell in col:
        try:
            if len(str(cell.value)) > max_length:
                max_length = len(cell.value)
        except:
            pass
    adjusted_width = (max_length + 2) * 1.2
    sheet.column_dimensions[column].width = adjusted_width

# Aplicar color rojo a las celdas negativas en columnas con prefijo 'DIF_'
red_font = Font(color="FF0000")

for col in sheet.iter_cols(min_row=2, min_col=1, max_col=sheet.max_column):
    col_name = sheet.cell(row=1, column=col[0].column).value
    if col_name.startswith('DIF_'):
        for cell in col:
            if isinstance(cell.value, (int, float)) and cell.value < 0:
                cell.font = red_font

# Guardar los cambios en el archivo Excel
wb.save(excel_path_2)

# %% [markdown]
# # Desde MZN

# %%
# ### RUTA MET LOC - ALEJANDRO (local)
# #ruta gpkg fin
# MAPA_TIPO_ruta = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\Loc_Tipologías_NAC.gpkg"
# # Leer la capa existente del GeoPackage base
# MAPA_TIPO_gdf = gpd.read_file(MAPA_TIPO_ruta, layer='Loc_SubTipologias_ue')

### RUTA MZN EQ - ALEJANDRO (SSD)
#ruta gpkg fin
MAPA_TIPO_ruta  = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\Mzn_Tipologías_NAC_ImpEq_BufferB.gpkg"
# Leer la capa existente del GeoPackage base
MAPA_TIPO_gdf = gpd.read_file(MAPA_TIPO_ruta, layer='Mzn_Subtipologias_UeEQ_filtrado')

# %% [markdown]
# ## Sumatoria y re-cálculo de indicadores

# %% [markdown]
# ### Resultados por Metrópoli

# %%
# # rutas excel - Alejandro (local) 
# excel_path = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\resultados_metropoli.xlsx"
# excel_path_2 = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\estadísticas_bruto_metropoli.xlsx")

# rutas excel - Alejandro (SSD) 
excel_path = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\resultados_metropoli.xlsx"
excel_path_2 = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\estadísticas_bruto_metropoli.xlsx"

# %%
# Filtrar polígonos por categoría 'Urbana' y 'Rural' con CALIF_CLAS diferente de '0'
MAPA_TIPO_urbana = MAPA_TIPO_gdf[MAPA_TIPO_gdf['AMBITO'] == 'Urbana']
MAPA_TIPO_rural = MAPA_TIPO_gdf[(MAPA_TIPO_gdf['AMBITO'] == 'Rural') & (MAPA_TIPO_gdf['CALIF_CLAS'] != '0')]

# Concatenar los GeoDataFrames filtrados
MAPA_TIPO_filtrado = pd.concat([MAPA_TIPO_urbana, MAPA_TIPO_rural])

# Columnas que se sumarán
columnas_a_sumar = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 
    'TVIVHAB2010', 'TVIVHAB2020', 'TVIVPAR2010', 'TVIVPAR2020',
    'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010', 'VIVPAR_HAB2020',
    'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
    'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 
    'VIV2C2010', 'VIV2C2020', 'VIV3C2010', 'VIV3C2020', 'area_ha',
    'UE_20', 'Emp_20', 'UE_10', 'Emp_10',
    'num_edu', 'num_sal', 'num_rec', 'num_ser', 
    'IMP_EDU', 'IMP_EDU_B', 'IMP_EDU_C', 
    'IMP_SAL', 'IMP_SAL_B', 'IMP_SAL_C', 
    'IMP_REC', 'IMP_REC_B', 'IMP_REC_C', 
    'IMP_SER', 'IMP_SER_B', 'IMP_SER_C'
]

# Sumar las columnas y agrupar por 'NOM_MET' y 'TIPO_MET'
MAPA_TIPO_sumado = MAPA_TIPO_filtrado.groupby(['CVE_MET','NOM_MET', 'TIPO_MET'])[columnas_a_sumar].sum(numeric_only=True).reset_index()

# Contar las localidades agrupadas
MAPA_TIPO_sumado['Localidades'] = MAPA_TIPO_filtrado.groupby(['NOM_MET', 'TIPO_MET']).size().values

# Recalcular los campos
MAPA_TIPO_sumado['DIFPOP'] = MAPA_TIPO_sumado['POPTOT2020'] - MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['DIFVIV'] = MAPA_TIPO_sumado['VIVTOT2020'] - MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['RELPOP'] = MAPA_TIPO_sumado['DIFPOP'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['RELVIV'] = MAPA_TIPO_sumado['DIFVIV'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['CVEPOP'] = np.where(MAPA_TIPO_sumado['RELPOP'] < -0.000000001, 'A', 'B')
MAPA_TIPO_sumado['CVEVIV'] = np.where(MAPA_TIPO_sumado['RELVIV'] < -.0703, '1',
                                      np.where((MAPA_TIPO_sumado['RELVIV'] >= -.0703) & (MAPA_TIPO_sumado['RELVIV'] <= .0703), 
                                               '2', '3'))
MAPA_TIPO_sumado['CVE'] = MAPA_TIPO_sumado['CVEPOP'] + MAPA_TIPO_sumado['CVEVIV'].astype(str)

conditions = [
    (MAPA_TIPO_sumado['POPTOT2020'] == 0),
    (MAPA_TIPO_sumado['POPTOT2010'] == 0) & (MAPA_TIPO_sumado['VIVTOT2010'] == 0) & (MAPA_TIPO_sumado['CVE'] == 'B3')
]
choices = ['DH', 'B3\'']
MAPA_TIPO_sumado['TIPOLOGIA'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE'])

MAPA_TIPO_sumado['DENS_POP10'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_POP20'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSPOP'] = MAPA_TIPO_sumado['DENS_POP20'] - MAPA_TIPO_sumado['DENS_POP10']

MAPA_TIPO_sumado['DENS_VIV10'] = MAPA_TIPO_sumado['VIVTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_VIV20'] = MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSVIV'] = MAPA_TIPO_sumado['DENS_VIV20'] - MAPA_TIPO_sumado['DENS_VIV10']

MAPA_TIPO_sumado['CUARTOS2010'] = ((MAPA_TIPO_sumado['VIV1C2010'] * 1) + (MAPA_TIPO_sumado['VIV2C2010'] * 2) + (MAPA_TIPO_sumado['VIV3C2010'] * 4))
MAPA_TIPO_sumado['CUARTOS2020'] = ((MAPA_TIPO_sumado['VIV1C2020'] * 1) + (MAPA_TIPO_sumado['VIV2C2020'] * 2) + (MAPA_TIPO_sumado['VIV3C2020'] * 4))

MAPA_TIPO_sumado['CPERC2010'] = MAPA_TIPO_sumado['CUARTOS2010'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['CPERC2020'] = MAPA_TIPO_sumado['CUARTOS2020'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_CPERC'] = MAPA_TIPO_sumado['CPERC2020'] - MAPA_TIPO_sumado['CPERC2010']

MAPA_TIPO_sumado['HABXVIV2010'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['HABXVIV2020'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_HABXVIV'] = MAPA_TIPO_sumado['HABXVIV2020'] - MAPA_TIPO_sumado['HABXVIV2010']


MAPA_TIPO_sumado['DESHABITACION_2010'] = MAPA_TIPO_sumado['VIVPAR_DES2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['DESHABITACION_2020'] = MAPA_TIPO_sumado['VIVPAR_DES2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_DESHAB'] = MAPA_TIPO_sumado['DESHABITACION_2020'] - MAPA_TIPO_sumado['DESHABITACION_2010']

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_POP'] = (((MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['POPTOT2010']) ** (1/10)) - 1) * 100
MAPA_TIPO_sumado['TASA_VIV'] = (((MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['VIVTOT2010']) ** (1/10)) - 1) * 100

def asignar_subtipologia_2010(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2010'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado

    
def asignar_subtipologia_2020(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2020'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado


# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2010'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2010, axis=1)

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2020'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2020, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA'] = MAPA_TIPO_sumado['TIPOLOGIA'].astype(str) + '-' + MAPA_TIPO_sumado['R_DESHAB_2020'].astype(str)

############################################indicadores DENUE

#Tamaño de unidades promedio: Empleados entre UE por manzana
MAPA_TIPO_sumado['TAMAÑO'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['UE_20']

# Calcular las sumas de POPTOT2020 y POPTOT2010 por CVE_MET
sum_emptot2020 = MAPA_TIPO_sumado.groupby('CVE_MET')['Emp_20'].transform('sum')
sum_emptot2010 = MAPA_TIPO_sumado.groupby('CVE_MET')['Emp_10'].transform('sum')

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_EMP_MET'] = (((sum_emptot2020 / sum_emptot2010) ** (1/10)) - 1) * 100

#resto de campos
MAPA_TIPO_sumado['DIF_EMP'] = MAPA_TIPO_sumado['Emp_20'] - MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['DIF_UEC'] = MAPA_TIPO_sumado['UE_20'] - MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['REL_EMP'] = MAPA_TIPO_sumado['DIF_EMP'] / MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['REL_UEC'] = MAPA_TIPO_sumado['DIF_UEC'] / MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['CVE_EMP'] = np.where(MAPA_TIPO_sumado['REL_EMP'] < -0.000000001, '1', '2')
MAPA_TIPO_sumado['CVE_UEC'] = np.where(MAPA_TIPO_sumado['REL_UEC'] < -.1, 'A',
                                   np.where((MAPA_TIPO_sumado['REL_UEC'] >= -.1) & (MAPA_TIPO_sumado['REL_UEC'] <= .1), 
                                            'B', 'C'))
MAPA_TIPO_sumado['CVE_ue'] = MAPA_TIPO_sumado['CVE_UEC'].astype(str) + MAPA_TIPO_sumado['CVE_EMP']
conditions = [
    (MAPA_TIPO_sumado['Emp_20'] == 0),
    (MAPA_TIPO_sumado['Emp_10'] == 0) & (MAPA_TIPO_sumado['UE_10'] == 0) & (MAPA_TIPO_sumado['CVE_ue'] == 'C2')
]
choices = ['00', 'C2+']
MAPA_TIPO_sumado['TIPOLOGIA_ue'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE_ue'])

MAPA_TIPO_sumado['DENS_EMP20'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_EMP10'] = MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['EPERC2010'] = MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['EPERC2020'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_EPERC'] = MAPA_TIPO_sumado['EPERC2020'] - MAPA_TIPO_sumado['EPERC2010']

MAPA_TIPO_sumado['DENS_UEC20'] = MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_UEC10'] = MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['UEPERC2010'] = MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['UEPERC2020'] = MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_UEPERC'] = MAPA_TIPO_sumado['UEPERC2020'] - MAPA_TIPO_sumado['UEPERC2010']

def asignar_subtipologia(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, 1, 30, 100]  # Modifica estos valores según tus necesidades
    
# Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[1]:
        return 'SUE'
    elif rangos_deshabitacion_grupo[1] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[2]:
        return 'MICRO'
    elif rangos_deshabitacion_grupo[2] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[3]:
        return 'MEDIANA'
    elif row['TAMAÑO'] >= rangos_deshabitacion_grupo[3]:
        return 'GRANDE'
    else:
        return '0'  # Valor predeterminado

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_TAM'] = MAPA_TIPO_sumado.apply(asignar_subtipologia, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA_ue'] = MAPA_TIPO_sumado['TIPOLOGIA_ue'].astype(str) + '-' + MAPA_TIPO_sumado['R_TAM'].astype(str)

###################################################################

MAPA_TIPO_sumado['NUM_EQ'] = MAPA_TIPO_sumado['num_edu'] + MAPA_TIPO_sumado['num_sal'] + MAPA_TIPO_sumado['num_rec'] + MAPA_TIPO_sumado['num_ser']

MAPA_TIPO_sumado['EQPERC2020'] = (MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['POPTOT2020'])*100

# Crear el campo Densidad de Equipamientos
MAPA_TIPO_sumado['DENS_EQ'] = MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['area_ha']

###################################################################

# Redondear a 3 decimales
MAPA_TIPO_sumado = MAPA_TIPO_sumado.round(3)

# Guardar los datos en un archivo Excel

MAPA_TIPO_sumado.to_excel(excel_path, index=False)

# Leer el archivo Excel
wb = openpyxl.load_workbook(excel_path)

# Seleccionar la hoja de cálculo
sheet = wb.active

# Ajustar el ancho de las columnas automáticamente
for col in sheet.columns:
    max_length = 0
    column = col[0].column_letter
    for cell in col:
        try:
            if len(str(cell.value)) > max_length:
                max_length = len(cell.value)
        except:
            pass
    adjusted_width = (max_length + 2) * 1.2
    sheet.column_dimensions[column].width = adjusted_width

# Aplicar color rojo a las celdas negativas en columnas con prefijo 'DIF_'
red_font = Font(color="FF0000")

for col in sheet.iter_cols(min_row=2, min_col=1, max_col=sheet.max_column):
    col_name = sheet.cell(row=1, column=col[0].column).value
    if col_name.startswith('DIF_'):
        for cell in col:
            if isinstance(cell.value, (int, float)) and cell.value < 0:
                cell.font = red_font

# Guardar los cambios en el archivo Excel
wb.save(excel_path_2)

# %% [markdown]
# ### Resultados por Municipio

# %%
# # rutas excel - Gerardo
# excel_path = 'C:/Users/ADMIN/Desktop/Ejercicio/Localidad/resultados_municipio.xlsx'
# excel_path_2 = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\estadísticas_bruto_metropoli.xlsx")

# # rutas excel - Alejandro (local) 
# excel_path = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\resultados_municipio.xlsx"
# excel_path_2 = r"C:\Users\Alejandro\Downloads\DATA\Tratados\NAC\DENUE_LOC_NAC\estadísticas_bruto_municipio.xlsx")

# rutas excel - Alejandro (SSD) 
excel_path = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\resultados_municipio.xlsx"
excel_path_2 = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\estadísticas_bruto_municipio.xlsx"

# %%
import pandas as pd
import numpy as np
import openpyxl
from openpyxl.styles import Font, PatternFill

# Filtrar polígonos por categoría 'Urbana' y 'Rural' con CALIF_CLAS diferente de '0'
MAPA_TIPO_urbana = MAPA_TIPO_gdf[MAPA_TIPO_gdf['AMBITO'] == 'Urbana']
MAPA_TIPO_rural = MAPA_TIPO_gdf[(MAPA_TIPO_gdf['AMBITO'] == 'Rural') & (MAPA_TIPO_gdf['CALIF_CLAS'] != '0')]

# Concatenar los GeoDataFrames filtrados
MAPA_TIPO_filtrado = pd.concat([MAPA_TIPO_urbana, MAPA_TIPO_rural])

# Columnas que se sumarán
columnas_a_sumar = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 
    'TVIVHAB2010', 'TVIVHAB2020', 'TVIVPAR2010', 'TVIVPAR2020',
    'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010', 'VIVPAR_HAB2020',
    'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
    'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 
    'VIV2C2010', 'VIV2C2020', 'VIV3C2010', 'VIV3C2020', 'area_ha',
    'UE_20', 'Emp_20', 'UE_10', 'Emp_10',
    'num_edu', 'num_sal', 'num_rec', 'num_ser', 'IMP_EDU', 'IMP_SAL', 'IMP_REC', 'IMP_SER']

# Sumar las columnas y agrupar por 'NOM_MET'
MAPA_TIPO_sumado = MAPA_TIPO_filtrado.groupby(['CVE_MET','CVEMUN','NOM_MET', 'TIPO_MET','TIPO_MUN'])[columnas_a_sumar].sum(numeric_only=True).reset_index()

# Contar las manzanas agrupadas
MAPA_TIPO_sumado['Localidades'] = MAPA_TIPO_filtrado.groupby(['CVEMUN', 'NOM_MET', 'TIPO_MET','TIPO_MUN']).size().values



# # Intentar cargar el archivo CSV con diferentes codificaciones y asegurar que las columnas sean string
# try:
#     agem_df = pd.read_csv("C:/Users/ADMIN/Downloads/AGEM.csv", usecols=['CVEMUN', 'NOM_MUN'], dtype=str, encoding='latin1')
# except UnicodeDecodeError:
#     agem_df = pd.read_csv("C:/Users/ADMIN/Downloads/AGEM.csv", usecols=['CVEMUN', 'NOM_MUN'], dtype=str, encoding='iso-8859-1')

# # Hacer el join con el archivo CSV basado en 'CVEMUN'
# MAPA_TIPO_sumado = pd.merge(MAPA_TIPO_sumado, agem_df, on='CVEMUN', how='left')


# Recalcular los campos
MAPA_TIPO_sumado['DIFPOP'] = MAPA_TIPO_sumado['POPTOT2020'] - MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['DIFVIV'] = MAPA_TIPO_sumado['VIVTOT2020'] - MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['RELPOP'] = MAPA_TIPO_sumado['DIFPOP'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['RELVIV'] = MAPA_TIPO_sumado['DIFVIV'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['CVEPOP'] = np.where(MAPA_TIPO_sumado['RELPOP'] < -0.000000001, 'A', 'B')
MAPA_TIPO_sumado['CVEVIV'] = np.where(MAPA_TIPO_sumado['RELVIV'] < -.0703, '1',
                                      np.where((MAPA_TIPO_sumado['RELVIV'] >= -.0703) & (MAPA_TIPO_sumado['RELVIV'] <= .0703), 
                                               '2', '3'))
MAPA_TIPO_sumado['CVE'] = MAPA_TIPO_sumado['CVEPOP'] + MAPA_TIPO_sumado['CVEVIV'].astype(str)

conditions = [
    (MAPA_TIPO_sumado['POPTOT2020'] == 0),
    (MAPA_TIPO_sumado['POPTOT2010'] == 0) & (MAPA_TIPO_sumado['VIVTOT2010'] == 0) & (MAPA_TIPO_sumado['CVE'] == 'B3')
]
choices = ['DH', 'B3\'']
MAPA_TIPO_sumado['TIPOLOGIA'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE'])

MAPA_TIPO_sumado['DENS_POP10'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_POP20'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSPOP'] = MAPA_TIPO_sumado['DENS_POP20'] - MAPA_TIPO_sumado['DENS_POP10']

MAPA_TIPO_sumado['DENS_VIV10'] = MAPA_TIPO_sumado['VIVTOT2010'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_VIV20'] = MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DIF_DENSVIV'] = MAPA_TIPO_sumado['DENS_VIV20'] - MAPA_TIPO_sumado['DENS_VIV10']

MAPA_TIPO_sumado['CUARTOS2010'] = ((MAPA_TIPO_sumado['VIV1C2010'] * 1) + (MAPA_TIPO_sumado['VIV2C2010'] * 2) + (MAPA_TIPO_sumado['VIV3C2010'] * 4))
MAPA_TIPO_sumado['CUARTOS2020'] = ((MAPA_TIPO_sumado['VIV1C2020'] * 1) + (MAPA_TIPO_sumado['VIV2C2020'] * 2) + (MAPA_TIPO_sumado['VIV3C2020'] * 4))

MAPA_TIPO_sumado['CPERC2010'] = MAPA_TIPO_sumado['CUARTOS2010'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['CPERC2020'] = MAPA_TIPO_sumado['CUARTOS2020'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_CPERC'] = MAPA_TIPO_sumado['CPERC2020'] - MAPA_TIPO_sumado['CPERC2010']

MAPA_TIPO_sumado['HABXVIV2010'] = MAPA_TIPO_sumado['POPTOT2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['HABXVIV2020'] = MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_HABXVIV'] = MAPA_TIPO_sumado['HABXVIV2020'] - MAPA_TIPO_sumado['HABXVIV2010']


MAPA_TIPO_sumado['DESHABITACION_2010'] = MAPA_TIPO_sumado['VIVPAR_DES2010'] / MAPA_TIPO_sumado['VIVTOT2010']
MAPA_TIPO_sumado['DESHABITACION_2020'] = MAPA_TIPO_sumado['VIVPAR_DES2020'] / MAPA_TIPO_sumado['VIVTOT2020']
MAPA_TIPO_sumado['DIF_DESHAB'] = MAPA_TIPO_sumado['DESHABITACION_2020'] - MAPA_TIPO_sumado['DESHABITACION_2010']

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_POP'] = (((MAPA_TIPO_sumado['POPTOT2020'] / MAPA_TIPO_sumado['POPTOT2010']) ** (1/10)) - 1) * 100
MAPA_TIPO_sumado['TASA_VIV'] = (((MAPA_TIPO_sumado['VIVTOT2020'] / MAPA_TIPO_sumado['VIVTOT2010']) ** (1/10)) - 1) * 100

def asignar_subtipologia_2010(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2010'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2010'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado

    
def asignar_subtipologia_2020(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, .0703, .1416, .2812]  # Modifica estos valores según tus necesidades
    
    # Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[1]:
        return 'a'
    elif rangos_deshabitacion_grupo[1] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[2]:
        return 'b'
    elif rangos_deshabitacion_grupo[2] <= row['DESHABITACION_2020'] < rangos_deshabitacion_grupo[3]:
        return 'c'
    elif row['DESHABITACION_2020'] >= rangos_deshabitacion_grupo[3]:
        return 'd'
    else:
        return '0'  # Valor predeterminado


# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2010'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2010, axis=1)

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_DESHAB_2020'] = MAPA_TIPO_sumado.apply(asignar_subtipologia_2020, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA'] = MAPA_TIPO_sumado['TIPOLOGIA'].astype(str) + '-' + MAPA_TIPO_sumado['R_DESHAB_2020'].astype(str)

############################################indicadores DENUE

#Tamaño de unidades promedio: Empleados entre UE por manzana
MAPA_TIPO_sumado['TAMAÑO'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['UE_20']

# Calcular las sumas de POPTOT2020 y POPTOT2010 por CVE_MET
sum_emptot2020 = MAPA_TIPO_sumado.groupby('CVEMUN')['Emp_20'].transform('sum')
sum_emptot2010 = MAPA_TIPO_sumado.groupby('CVEMUN')['Emp_10'].transform('sum')

# Calcular TASA_POP_MUN
MAPA_TIPO_sumado['TASA_EMP_MUN'] = (((sum_emptot2020 / sum_emptot2010) ** (1/10)) - 1) * 100

#resto de campos
MAPA_TIPO_sumado['DIF_EMP'] = MAPA_TIPO_sumado['Emp_20'] - MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['DIF_UEC'] = MAPA_TIPO_sumado['UE_20'] - MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['REL_EMP'] = MAPA_TIPO_sumado['DIF_EMP'] / MAPA_TIPO_sumado['Emp_10']
MAPA_TIPO_sumado['REL_UEC'] = MAPA_TIPO_sumado['DIF_UEC'] / MAPA_TIPO_sumado['UE_10']
MAPA_TIPO_sumado['CVE_EMP'] = np.where(MAPA_TIPO_sumado['REL_EMP'] < -0.000000001, '1', '2')
MAPA_TIPO_sumado['CVE_UEC'] = np.where(MAPA_TIPO_sumado['REL_UEC'] < -.1, 'A',
                                   np.where((MAPA_TIPO_sumado['REL_UEC'] >= -.1) & (MAPA_TIPO_sumado['REL_UEC'] <= .1), 
                                            'B', 'C'))
MAPA_TIPO_sumado['CVE_ue'] = MAPA_TIPO_sumado['CVE_UEC'].astype(str) + MAPA_TIPO_sumado['CVE_EMP']
conditions = [
    (MAPA_TIPO_sumado['Emp_20'] == 0),
    (MAPA_TIPO_sumado['Emp_10'] == 0) & (MAPA_TIPO_sumado['UE_10'] == 0) & (MAPA_TIPO_sumado['CVE_ue'] == 'C2')
]
choices = ['00', 'C2+']
MAPA_TIPO_sumado['TIPOLOGIA_ue'] = np.select(conditions, choices, default=MAPA_TIPO_sumado['CVE_ue'])

MAPA_TIPO_sumado['DENS_EMP20'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_EMP10'] = MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['EPERC2010'] = MAPA_TIPO_sumado['Emp_10'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['EPERC2020'] = MAPA_TIPO_sumado['Emp_20'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_EPERC'] = MAPA_TIPO_sumado['EPERC2020'] - MAPA_TIPO_sumado['EPERC2010']

MAPA_TIPO_sumado['DENS_UEC20'] = MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['area_ha']
MAPA_TIPO_sumado['DENS_UEC10'] = MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['area_ha']

MAPA_TIPO_sumado['UEPERC2010'] = MAPA_TIPO_sumado['UE_10'] / MAPA_TIPO_sumado['POPTOT2010']
MAPA_TIPO_sumado['UEPERC2020'] = MAPA_TIPO_sumado['UE_20'] / MAPA_TIPO_sumado['POPTOT2020']
MAPA_TIPO_sumado['DIF_UEPERC'] = MAPA_TIPO_sumado['UEPERC2020'] - MAPA_TIPO_sumado['UEPERC2010']


def asignar_subtipologia(row):
    # Valores específicos para deshabitación
    rangos_deshabitacion_grupo = [0, 1, 30, 100]  # Modifica estos valores según tus necesidades
    
# Asignar subtipología según los rangos definidos
    if rangos_deshabitacion_grupo[0] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[1]:
        return 'SUE'
    elif rangos_deshabitacion_grupo[1] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[2]:
        return 'MICRO'
    elif rangos_deshabitacion_grupo[2] <= row['TAMAÑO'] < rangos_deshabitacion_grupo[3]:
        return 'MEDIANA'
    elif row['TAMAÑO'] >= rangos_deshabitacion_grupo[3]:
        return 'GRANDE'
    else:
        return '0'  # Valor predeterminado

# Crear un nuevo campo 'R_DESHAB' y llenarlo con las subtipologías asignadas
MAPA_TIPO_sumado['R_TAM'] = MAPA_TIPO_sumado.apply(asignar_subtipologia, axis=1)

# Crear el campo SUBTIPOLOGÍA
MAPA_TIPO_sumado['SUBTIPOLOGÍA_ue'] = MAPA_TIPO_sumado['TIPOLOGIA_ue'].astype(str) + '-' + MAPA_TIPO_sumado['R_TAM'].astype(str)

###################################################################

MAPA_TIPO_sumado['NUM_EQ'] = MAPA_TIPO_sumado['num_edu'] + MAPA_TIPO_sumado['num_sal'] + MAPA_TIPO_sumado['num_rec'] + MAPA_TIPO_sumado['num_ser']

MAPA_TIPO_sumado['EQPERC2020'] = (MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['POPTOT2020'])*100

# Crear el campo Densidad de Equipamientos
MAPA_TIPO_sumado['DENS_EQ'] = MAPA_TIPO_sumado['NUM_EQ'] / MAPA_TIPO_sumado['area_ha']

###################################################################

# Redondear a 3 decimales
MAPA_TIPO_sumado = MAPA_TIPO_sumado.round(3)

# Reordenar columnas: 'NOM_MUN', 'NOM_MET', 'TIPO_MET' al inicio y 'TIPO_MUN' al final
column_order = ['CVEMUN', 'NOM_MET', 'TIPO_MET'] + [col for col in MAPA_TIPO_sumado.columns if col not in ['CVEMUN', 'NOM_MET', 'TIPO_MET', 'TIPO_MUN']] + ['TIPO_MUN']
MAPA_TIPO_sumado = MAPA_TIPO_sumado[column_order]

# Guardar los datos en un archivo Excel

MAPA_TIPO_sumado.to_excel(excel_path, index=False)

# Leer el archivo Excel
wb = openpyxl.load_workbook(excel_path)

# Seleccionar la hoja de cálculo
sheet = wb.active

# Ajustar el ancho de las columnas automáticamente
for col in sheet.columns:
    max_length = 0
    column = col[0].column_letter
    for cell in col:
        try:
            if len(str(cell.value)) > max_length:
                max_length = len(cell.value)
        except:
            pass
    adjusted_width = (max_length + 2) * 1.2
    sheet.column_dimensions[column].width = adjusted_width

# Aplicar color rojo a las celdas negativas en columnas con prefijo 'DIF_'
red_font = Font(color="FF0000")

for col in sheet.iter_cols(min_row=2, min_col=1, max_col=sheet.max_column):
    col_name = sheet.cell(row=1, column=col[0].column).value
    if col_name.startswith('DIF_'):
        for cell in col:
            if isinstance(cell.value, (int, float)) and cell.value < 0:
                cell.font = red_font

# Guardar los cambios en el archivo Excel
wb.save(excel_path_2)

# %% [markdown]
# ## Agrupaciones categóricas
# Agrupar por niv deshab, promedios (numéricos)

# %% [markdown]
# ### Por tipología

# %%
#Rutas salida 
ruta_promedios = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\promedios.xlsx"
ruta_porcentajes = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes.xlsx"
ruta_conteos = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\conteos.xlsx"
ruta_porcentajes_conteos = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx"
ruta_sumas_cat = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\sumas_categoria.xlsx"

# %%
# Código para calcular promedios por categoría de R_DESHAB y exportar
columnas_promedio = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 'TVIVHAB2010', 'TVIVHAB2020',
                     'TVIVPAR2010', 'TVIVPAR2020', 'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010',
                     'VIVPAR_HAB2020', 'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
                     'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 'VIV2C2010', 'VIV2C2020',
                     'VIV3C2010', 'VIV3C2020', 'DENS_POP10', 'DENS_POP20', 'DENS_VIV10', 'DENS_VIV20',
                     'CUARTOS2010', 'CUARTOS2020', 'CPERC2010', 'CPERC2020', 'HABXVIV2010', 'HABXVIV2020',
                     'UE_10', 'Emp_10', 'UE_20', 'Emp_20', 'TAMAÑO', 'TASA_EMP_MUN', 'DENS_EMP20', 'DENS_EMP10',
                     'DENS_UEC20', 'DENS_UEC10', 'num_edu', 'num_sal', 'num_rec', 'num_ser', 'IMP_EDU', 'IMP_EDU_B',
                     'IMP_EDU_C', 'IMP_SAL', 'IMP_SAL_B', 'IMP_SAL_C', 'IMP_REC', 'IMP_REC_B', 'IMP_REC_C', 'IMP_SER',
                     'IMP_SER_B', 'IMP_SER_C']

columnas_porcentaje = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 'TVIVHAB2010', 'TVIVHAB2020',
                     'TVIVPAR2010', 'TVIVPAR2020', 'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010',
                     'VIVPAR_HAB2020', 'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
                     'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 'VIV2C2010', 'VIV2C2020',
                     'VIV3C2010', 'VIV3C2020', 'DENS_POP10', 'DENS_POP20', 'DENS_VIV10', 'DENS_VIV20',
                     'CUARTOS2010', 'CUARTOS2020', 'CPERC2010', 'CPERC2020', 'HABXVIV2010', 'HABXVIV2020',
                     'UE_10', 'Emp_10', 'UE_20', 'Emp_20', 'TAMAÑO', 'TASA_EMP_MUN', 'DENS_EMP20', 'DENS_EMP10',
                     'DENS_UEC20', 'DENS_UEC10', 'num_edu', 'num_sal', 'num_rec', 'num_ser', 'IMP_EDU', 'IMP_EDU_B',
                     'IMP_EDU_C', 'IMP_SAL', 'IMP_SAL_B', 'IMP_SAL_C', 'IMP_REC', 'IMP_REC_B', 'IMP_REC_C', 'IMP_SER',
                     'IMP_SER_B', 'IMP_SER_C']

columnas_conteo = ['AMBITO', 'TIPOMZA', 'TIPOLOGIA', 'R_DESHAB', 'SUBTIPOLOGÍA', 'CVE_EMP', 'CVE_UEC', 'CVE_ue',
                   'TIPOLOGIA_ue', 'R_TAM', 'SUBTIPOLOGÍA_ue', 'CVE_EDU_C', 'CVE_SAL_C', 'CVE_REC_C', 'CVE_SER_C', 'CVE_EQ_C']

columnas_porcentaje_2 = ['AMBITO', 'TIPOMZA', 'TIPOLOGIA', 'R_DESHAB', 'SUBTIPOLOGÍA', 'CVE_EMP', 'CVE_UEC', 'CVE_ue',
                   'TIPOLOGIA_ue', 'R_TAM', 'SUBTIPOLOGÍA_ue', 'CVE_EDU_C', 'CVE_SAL_C', 'CVE_REC_C', 'CVE_SER_C', 'CVE_EQ_C']

columnas_conteo_2 = ['R_DESHAB']

columnas_suma = ['VIVPAR_DES2020']

# Agrupación para promedios
def calcular_promedios(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
    categorias = gdf['TIPOLOGIA'].unique()
    for categoria in categorias:
        filtro = gdf[gdf['TIPOLOGIA'] == categoria]
        promedios = filtro.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET'])[columnas_promedio].mean().reset_index()
        # Reemplazar "'" al final con "_" en lugar de eliminarlo
        sheet_name = f"TIPOLOGIA_{categoria}".rstrip("'") + "_" if categoria.endswith("'") else f"TIPOLOGIA_{categoria}"
        promedios.to_excel(writer, sheet_name=sheet_name, index=False)
    writer.close()

# Código para calcular porcentajes por categoría de TIPOLOGIA y exportar
def calcular_porcentajes(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
    categorias = gdf['TIPOLOGIA'].unique()
    for categoria in categorias:
        filtro = gdf[gdf['TIPOLOGIA'] == categoria]
        totales = gdf.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET'])[columnas_porcentaje].sum()
        porcentajes = filtro.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET'])[columnas_porcentaje].sum() / totales
        porcentajes = porcentajes.reset_index()
        # Reemplazar "'" al final con "_" en lugar de eliminarlo
        sheet_name = f"TIPOLOGIA_{categoria}".rstrip("'") + "_" if categoria.endswith("'") else f"TIPOLOGIA_{categoria}"
        porcentajes.to_excel(writer, sheet_name=sheet_name, index=False)
    writer.close()

# Código para calcular conteos por categoría de TIPOLOGIA y exportar
def calcular_conteos(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
    categorias = gdf['TIPOLOGIA'].unique()

    for categoria in categorias:
        # Filtrar datos por categoría y establecer índice
        filtro = gdf[gdf['TIPOLOGIA'] == categoria].set_index(['CVE_MET', 'NOM_MET', 'TIPO_MET'])
        conteos = pd.DataFrame()

        for columna in columnas_conteo:
            valores_unicos = filtro[columna].dropna().unique()
            for valor in valores_unicos:
                nombre_columna = f"{columna}_{valor}"
                conteos[nombre_columna] = filtro.groupby(level=[0, 1, 2])[columna].apply(lambda x: (x == valor).sum())
        
        # Restaurar índices originales
        conteos.reset_index(inplace=True)
        
        # Reemplazar "'" al final con "_" en lugar de eliminarlo
        sheet_name = f"TIPOLOGIA_{categoria}".rstrip("'") + "_" if categoria.endswith("'") else f"TIPOLOGIA_{categoria}"
        
        # Exportar resultados a Excel
        conteos.to_excel(writer, sheet_name=sheet_name, index=False)

    writer.close()

# Código para calcular porcentajes de conteos por categoría de TIPOLOGIA y exportar
def calcular_porcentajes_conteos(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')

    # Calcular el total de registros por agrupación
    total_registros = gdf.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET']).size().rename('total_registros')

    categorias = gdf['TIPOLOGIA'].unique()
    for categoria in categorias:
        # Filtrar datos por categoría y establecer índice
        filtro = gdf[gdf['TIPOLOGIA'] == categoria].set_index(['CVE_MET', 'NOM_MET', 'TIPO_MET'])
        porcentajes = pd.DataFrame()

        for columna in columnas_porcentaje_2:
            valores_unicos = filtro[columna].dropna().unique()
            for valor in valores_unicos:
                nombre_columna = f"{columna}_{valor}"
                conteo = filtro.groupby(level=[0, 1, 2])[columna].apply(lambda x: (x == valor).sum())
                
                # Alinear el conteo con el índice total
                conteo = conteo.reindex(total_registros.index, fill_value=0)
                
                # Calcular el porcentaje
                porcentajes[nombre_columna] = conteo / total_registros.values
        
        # Combinar índices originales
        porcentajes = porcentajes.join(total_registros).reset_index()
        
        # Reemplazar "'" al final con "_" en lugar de eliminarlo
        sheet_name = f"TIPOLOGIA_{categoria}".rstrip("'") + "_" if categoria.endswith("'") else f"TIPOLOGIA_{categoria}"
        
        # Exportar resultados a Excel
        porcentajes.to_excel(writer, sheet_name=sheet_name, index=False)

    writer.close()

import pandas as pd

def calcular_sumas_por_categoria(gdf, output_path):
    # Crear un escritor para el archivo Excel
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')

    # Obtener las categorías únicas de R_DESHAB
    categorias = gdf['TIPOLOGIA'].unique()

    for categoria in categorias:
        # Filtrar datos por categoría y establecer índice
        filtro = gdf[gdf['TIPOLOGIA'] == categoria].set_index(['CVE_MET', 'NOM_MET', 'TIPO_MET'])

        # DataFrame para almacenar resultados de la categoría actual
        resultados = pd.DataFrame()

        for columna_conteo in columnas_conteo_2:
            valores_unicos = filtro[columna_conteo].dropna().unique()

            for valor_unico in valores_unicos:
                for columna_suma in columnas_suma:
                    # Nombre de la columna combinando columna_conteo, valor y columna_suma
                    nombre_columna = f"{columna_conteo}_{valor_unico}_{columna_suma}"

                    # Calcular la suma para cada combinación
                    resultados[nombre_columna] = (
                        filtro.groupby(level=[0, 1, 2]).apply(
                            lambda x: x[x[columna_conteo] == valor_unico][columna_suma].sum()
                        )
                    )

        # Restaurar índices originales
        resultados.reset_index(inplace=True)
        
        # Reemplazar "'" al final con "_" en lugar de eliminarlo
        sheet_name = f"TIPOLOGIA_{categoria}".rstrip("'") + "_" if categoria.endswith("'") else f"TIPOLOGIA_{categoria}"
        
        # Exportar resultados a una hoja de Excel
        resultados.to_excel(writer, sheet_name=sheet_name, index=False)

    # Guardar y cerrar el archivo Excel
    writer.close()

# %%
# Ejemplo de uso:
calcular_promedios(MAPA_TIPO_gdf, ruta_promedios)
calcular_porcentajes(MAPA_TIPO_gdf, ruta_porcentajes)

calcular_conteos(MAPA_TIPO_gdf, ruta_conteos)
calcular_porcentajes_conteos(MAPA_TIPO_gdf, ruta_porcentajes_conteos)

# %%
# Ejemplo de uso
calcular_sumas_por_categoria(MAPA_TIPO_gdf, ruta_sumas_cat)

# %% [markdown]
# ### Por subtipología

# %%
#Rutas salida 
ruta_promedios = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\promedios.xlsx"
ruta_porcentajes = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\porcentajes.xlsx"
ruta_conteos = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\conteos.xlsx"
ruta_porcentajes_conteos = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\porcentajes_conteos.xlsx"
ruta_sumas_cat = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\sumas_categoria.xlsx"

# %%
# Código para calcular promedios por categoría de R_DESHAB y exportar
columnas_promedio = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 'TVIVHAB2010', 'TVIVHAB2020',
                     'TVIVPAR2010', 'TVIVPAR2020', 'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010',
                     'VIVPAR_HAB2020', 'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
                     'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 'VIV2C2010', 'VIV2C2020',
                     'VIV3C2010', 'VIV3C2020', 'DENS_POP10', 'DENS_POP20', 'DENS_VIV10', 'DENS_VIV20',
                     'CUARTOS2010', 'CUARTOS2020', 'CPERC2010', 'CPERC2020', 'HABXVIV2010', 'HABXVIV2020',
                     'UE_10', 'Emp_10', 'UE_20', 'Emp_20', 'TAMAÑO', 'TASA_EMP_MUN', 'DENS_EMP20', 'DENS_EMP10',
                     'DENS_UEC20', 'DENS_UEC10', 'num_edu', 'num_sal', 'num_rec', 'num_ser', 'IMP_EDU', 'IMP_EDU_B',
                     'IMP_EDU_C', 'IMP_SAL', 'IMP_SAL_B', 'IMP_SAL_C', 'IMP_REC', 'IMP_REC_B', 'IMP_REC_C', 'IMP_SER',
                     'IMP_SER_B', 'IMP_SER_C']

columnas_porcentaje = ['POPTOT2010', 'POPTOT2020', 'VIVTOT2010', 'VIVTOT2020', 'TVIVHAB2010', 'TVIVHAB2020',
                     'TVIVPAR2010', 'TVIVPAR2020', 'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010',
                     'VIVPAR_HAB2020', 'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010', 'OCUPVIVPAR2020',
                     'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010', 'VIV1C2020', 'VIV2C2010', 'VIV2C2020',
                     'VIV3C2010', 'VIV3C2020', 'DENS_POP10', 'DENS_POP20', 'DENS_VIV10', 'DENS_VIV20',
                     'CUARTOS2010', 'CUARTOS2020', 'CPERC2010', 'CPERC2020', 'HABXVIV2010', 'HABXVIV2020',
                     'UE_10', 'Emp_10', 'UE_20', 'Emp_20', 'TAMAÑO', 'TASA_EMP_MUN', 'DENS_EMP20', 'DENS_EMP10',
                     'DENS_UEC20', 'DENS_UEC10', 'num_edu', 'num_sal', 'num_rec', 'num_ser', 'IMP_EDU', 'IMP_EDU_B',
                     'IMP_EDU_C', 'IMP_SAL', 'IMP_SAL_B', 'IMP_SAL_C', 'IMP_REC', 'IMP_REC_B', 'IMP_REC_C', 'IMP_SER',
                     'IMP_SER_B', 'IMP_SER_C']

columnas_conteo = ['AMBITO', 'TIPOMZA', 'TIPOLOGIA', 'R_DESHAB', 'SUBTIPOLOGÍA', 'CVE_EMP', 'CVE_UEC', 'CVE_ue',
                   'TIPOLOGIA_ue', 'R_TAM', 'SUBTIPOLOGÍA_ue', 'CVE_EDU_C', 'CVE_SAL_C', 'CVE_REC_C', 'CVE_SER_C', 'CVE_EQ_C']

columnas_porcentaje_2 = ['AMBITO', 'TIPOMZA', 'TIPOLOGIA', 'R_DESHAB', 'SUBTIPOLOGÍA', 'CVE_EMP', 'CVE_UEC', 'CVE_ue',
                   'TIPOLOGIA_ue', 'R_TAM', 'SUBTIPOLOGÍA_ue', 'CVE_EDU_C', 'CVE_SAL_C', 'CVE_REC_C', 'CVE_SER_C', 'CVE_EQ_C']

columnas_conteo_2 = ['TIPOLOGIA']

columnas_suma = ['VIVPAR_DES2020']

# Agrupación para promedios
def calcular_promedios(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
    categorias = gdf['R_DESHAB'].unique()
    for categoria in categorias:
        filtro = gdf[gdf['R_DESHAB'] == categoria]
        promedios = filtro.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET'])[columnas_promedio].mean().reset_index()
        promedios.to_excel(writer, sheet_name=f"R_DESHAB_{categoria}", index=False)
    writer.close()

# Código para calcular porcentajes por categoría de R_DESHAB y exportar
def calcular_porcentajes(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
    categorias = gdf['R_DESHAB'].unique()
    for categoria in categorias:
        filtro = gdf[gdf['R_DESHAB'] == categoria]
        totales = gdf.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET'])[columnas_porcentaje].sum()
        porcentajes = filtro.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET'])[columnas_porcentaje].sum() / totales
        porcentajes = porcentajes.reset_index()
        porcentajes.to_excel(writer, sheet_name=f"R_DESHAB_{categoria}", index=False)
    writer.close()

# Código para calcular conteos por categoría de R_DESHAB y exportar
def calcular_conteos(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')
    categorias = gdf['R_DESHAB'].unique()

    for categoria in categorias:
        # Filtrar datos por categoría y establecer índice
        filtro = gdf[gdf['R_DESHAB'] == categoria].set_index(['CVE_MET', 'NOM_MET', 'TIPO_MET'])
        conteos = pd.DataFrame()

        for columna in columnas_conteo:
            valores_unicos = filtro[columna].dropna().unique()
            for valor in valores_unicos:
                nombre_columna = f"{columna}_{valor}"
                conteos[nombre_columna] = filtro.groupby(level=[0, 1, 2])[columna].apply(lambda x: (x == valor).sum())
        
        # Restaurar índices originales
        conteos.reset_index(inplace=True)

        # Exportar resultados a Excel
        conteos.to_excel(writer, sheet_name=f"R_DESHAB_{categoria}", index=False)

    writer.close()

# Código para calcular porcentajes de conteos por categoría de R_DESHAB y exportar
def calcular_porcentajes_conteos(gdf, output_path):
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')

    # Calcular el total de registros por agrupación
    total_registros = gdf.groupby(['CVE_MET', 'NOM_MET', 'TIPO_MET']).size().rename('total_registros')

    categorias = gdf['R_DESHAB'].unique()
    for categoria in categorias:
        # Filtrar datos por categoría y establecer índice
        filtro = gdf[gdf['R_DESHAB'] == categoria].set_index(['CVE_MET', 'NOM_MET', 'TIPO_MET'])
        porcentajes = pd.DataFrame()

        for columna in columnas_porcentaje_2:
            valores_unicos = filtro[columna].dropna().unique()
            for valor in valores_unicos:
                nombre_columna = f"{columna}_{valor}"
                conteo = filtro.groupby(level=[0, 1, 2])[columna].apply(lambda x: (x == valor).sum())
                
                # Alinear el conteo con el índice total
                conteo = conteo.reindex(total_registros.index, fill_value=0)
                
                # Calcular el porcentaje
                porcentajes[nombre_columna] = conteo / total_registros.values
        
        # Combinar índices originales
        porcentajes = porcentajes.join(total_registros).reset_index()

        # Exportar resultados a Excel
        porcentajes.to_excel(writer, sheet_name=f"R_DESHAB_{categoria}", index=False)

    writer.close()


import pandas as pd

def calcular_sumas_por_categoria(gdf, output_path):
    # Crear un escritor para el archivo Excel
    writer = pd.ExcelWriter(output_path, engine='xlsxwriter')

    # Obtener las categorías únicas de R_DESHAB
    categorias = gdf['R_DESHAB'].unique()

    for categoria in categorias:
        # Filtrar datos por categoría y establecer índice
        filtro = gdf[gdf['R_DESHAB'] == categoria].set_index(['CVE_MET', 'NOM_MET', 'TIPO_MET'])

        # DataFrame para almacenar resultados de la categoría actual
        resultados = pd.DataFrame()

        for columna_conteo in columnas_conteo_2:
            valores_unicos = filtro[columna_conteo].dropna().unique()

            for valor_unico in valores_unicos:
                for columna_suma in columnas_suma:
                    # Nombre de la columna combinando columna_conteo, valor y columna_suma
                    nombre_columna = f"{columna_conteo}_{valor_unico}_{columna_suma}"

                    # Calcular la suma para cada combinación
                    resultados[nombre_columna] = (
                        filtro.groupby(level=[0, 1, 2]).apply(
                            lambda x: x[x[columna_conteo] == valor_unico][columna_suma].sum()
                        )
                    )

        # Restaurar índices originales
        resultados.reset_index(inplace=True)

        # Exportar resultados a una hoja de Excel
        resultados.to_excel(writer, sheet_name=f"R_DESHAB_{categoria}", index=False)

    # Guardar y cerrar el archivo Excel
    writer.close()

# %%
# Ejemplo de uso:
calcular_promedios(MAPA_TIPO_gdf, ruta_promedios)
calcular_porcentajes(MAPA_TIPO_gdf, ruta_porcentajes)

# %%
calcular_conteos(MAPA_TIPO_gdf, ruta_conteos)
calcular_porcentajes_conteos(MAPA_TIPO_gdf, ruta_porcentajes_conteos)

# %%
# Ejemplo de uso
calcular_sumas_por_categoria(MAPA_TIPO_gdf, ruta_sumas_cat)

# %% [markdown]
# # a
