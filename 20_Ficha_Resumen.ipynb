# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
# rutas excel - Alejandro (SSD)

# desde LOC
ruta_loc = r"Z:\VOCES\DATA\Tratados\NAC\INT_LOC_NAC\resultados_metropoli.xlsx"

# desde MZN
ruta_mzn = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\resultados_metropoli.xlsx"
ruta_mzn_prom = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\promedios.xlsx"
ruta_mzn_porc = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\porcentajes.xlsx"
ruta_mzn_cont = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\conteos.xlsx"
ruta_mzn_porc_cont = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\porcentajes_conteos.xlsx"

# %% [markdown]
# # Revisión de indicadores disponibles

# %%
# Cargar la base de datos
loc = pd.read_excel(ruta_loc)
mzn = pd.read_excel(ruta_mzn)
mzn_prom_a = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_a')
mzn_porc_a = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_a')
mzn_cont_a = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_a')
mzn_porc_cont_a = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_a')
mzn_prom_b = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_b')
mzn_porc_b = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_b')
mzn_cont_b = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_b')
mzn_porc_cont_b = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_b')
mzn_prom_c = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_c')
mzn_porc_c = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_c')
mzn_cont_c = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_c')
mzn_porc_cont_c = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_c')
mzn_prom_d = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_d')
mzn_porc_d = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_d')
mzn_cont_d = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_d')
mzn_porc_cont_d = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_d')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[18], line 4
#       2 loc = pd.read_excel(ruta_loc)
#       3 mzn = pd.read_excel(ruta_mzn)
# ----> 4 mzn_prom_a = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_a')
#       5 mzn_porc_a = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_a')
#       6 mzn_cont_a = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_a')
#
# File ~\anaconda3\Lib\site-packages\pandas\io\excel\_base.py:495, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     493 if not isinstance(io, ExcelFile):
#     494     should_close = True
# --> 495     io = ExcelFile(
#     496         io,
# ...

# %%
mzn
# Out:
#     CVE_MET              NOM_MET             TIPO_MET  POPTOT2010  POPTOT2020  VIVTOT2010  VIVTOT2020  TVIVHAB2010  TVIVHAB2020  TVIVPAR2010  TVIVPAR2020  TVIVPARHAB2010  TVIVPARHAB2020  VIVPAR_HAB2010  VIVPAR_HAB2020  VIVPAR_UT2010  VIVPAR_UT2020  OCUPVIVPAR2010  OCUPVIVPAR2020  VIVPAR_DES2010  VIVPAR_DES2020  VIV1C2010  VIV1C2020  VIV2C2010  VIV2C2020  VIV3C2010  VIV3C2020    area_ha  UE_20  Emp_20  UE_10  Emp_10  num_edu  num_sal  num_rec  num_ser  IMP_EDU  IMP_EDU_B  IMP_EDU_C  IMP_SAL  IMP_SAL_B  IMP_SAL_C  IMP_REC  IMP_REC_B  IMP_REC_C  IMP_SER  IMP_SER_B  IMP_SER_C  Localidades  DIFPOP  DIFVIV  RELPOP  RELVIV CVEPOP  CVEVIV CVE TIPOLOGIA  DENS_POP10  DENS_POP20  DIF_DENSPOP  DENS_VIV10  DENS_VIV20  DIF_DENSVIV  CUARTOS2010  CUARTOS2020  CPERC2010  CPERC2020  DIF_CPERC  HABXVIV2010  HABXVIV2020  DIF_HABXVIV  DESHABITACION_2010  DESHABITACION_2020  DIF_DESHAB  TASA_POP  TASA_VIV R_DESHAB_2010 R_DESHAB_2020 SUBTIPOLOGÍA  TAMAÑO  TASA_EMP_MET  DIF_EMP  DIF_UEC  REL_EMP  REL_UEC  C
# ...

# %%
# Verificar columnas del DF, para ver columnas a sumar, y columnas a recalcular

# Asegúrate de que pandas muestre todas las columnas y expanda el ancho de la visualización
pd.set_option('display.max_columns', None)  # Muestra todas las columnas
pd.set_option('display.max_colwidth', None)  # No limite el ancho de las columnas
pd.set_option('display.expand_frame_repr', False)  # Evita el corte de DataFrames grandes

print('Columnas localidad:')
print(loc.columns)
print('Columnas manzana:')
print(mzn.columns)
print('Columnas promedios:')
print(mzn_prom.columns)
print('Columnas porcentajes:')
print(mzn_porc.columns)
print('Columnas conteos de manzanas:')
print(mzn_cont.columns)
print('Columnas porcentajes de conteos:')
print(mzn_porc_cont.columns)
# Out:
# Columnas localidad:
# Index(['CVE_MET', 'NOM_MET', 'TIPO_MET', 'POPTOT2010', 'POPTOT2020',
#        'VIVTOT2010', 'VIVTOT2020', 'TVIVHAB2010', 'TVIVHAB2020', 'TVIVPAR2010',
#        'TVIVPAR2020', 'TVIVPARHAB2010', 'TVIVPARHAB2020', 'VIVPAR_HAB2010',
#        'VIVPAR_HAB2020', 'VIVPAR_UT2010', 'VIVPAR_UT2020', 'OCUPVIVPAR2010',
#        'OCUPVIVPAR2020', 'VIVPAR_DES2010', 'VIVPAR_DES2020', 'VIV1C2010',
#        'VIV1C2020', 'VIV2C2010', 'VIV2C2020', 'VIV3C2010', 'VIV3C2020',
#        'area_ha', 'UE_20', 'Emp_20', 'UE_10', 'Emp_10', 'num_edu', 'num_sal',
#        'num_rec', 'num_ser', 'Localidades', 'DIFPOP', 'DIFVIV', 'RELPOP',
#        'RELVIV', 'CVEPOP', 'CVEVIV', 'CVE', 'TIPOLOGIA', 'DENS_POP10',
#        'DENS_POP20', 'DIF_DENSPOP', 'DENS_VIV10', 'DENS_VIV20', 'DIF_DENSVIV',
#        'CUARTOS2010', 'CUARTOS2020', 'CPERC2010', 'CPERC2020', 'DIF_CPERC',
#        'HABXVIV2010', 'HABXVIV2020', 'DIF_HABXVIV', 'DESHABITACION_2010',
# ...

# %%
# Crear una lista única de columnas
dataframes = [loc, mzn, mzn_prom, mzn_porc, mzn_cont, mzn_porc_cont]  # Lista de tus DataFrames
columnas_unicas = set(col for df in dataframes for col in df.columns)

columnas_unicas
# Out:
# {'AMBITO_Rural',
#  'AMBITO_Urbana',
#  'CPERC2010',
#  'CPERC2020',
#  'CUARTOS2010',
#  'CUARTOS2020',
#  'CVE',
#  'CVEPOP',
#  'CVEVIV',
#  'CVE_EDU_C_C',
#  'CVE_EDU_C_D',
#  'CVE_EDU_C_S',
#  'CVE_EMP',
#  'CVE_EMP_1',
#  'CVE_EMP_2',
#  'CVE_EQ_C_A',
#  'CVE_EQ_C_B',
#  'CVE_EQ_C_C',
#  'CVE_EQ_C_D',
#  'CVE_EQ_C_E',
#  'CVE_MET',
#  'CVE_REC_C_C',
#  'CVE_REC_C_D',
#  'CVE_REC_C_S',
#  'CVE_SAL_C_C',
#  'CVE_SAL_C_D',
#  'CVE_SAL_C_S',
#  'CVE_SER_C_C',
#  'CVE_SER_C_D',
#  'CVE_SER_C_S',
#  'CVE_UEC',
#  'CVE_UEC_A',
#  'CVE_UEC_B',
#  'CVE_UEC_C',
#  'CVE_ue',
#  'CVE_ue_A1',
#  'CVE_ue_A2',
#  'CVE_ue_B1',
#  'CVE_ue_B2',
#  'CVE_ue_C1',
#  'CVE_ue_C2',
#  'DENS_EMP10',
#  'DENS_EMP20',
#  'DENS_POP10',
#  'DENS_POP20',
#  'DENS_UEC10',
#  'DENS_UEC20',
#  'DENS_VIV10',
#  'DENS_VIV20',
#  'DESHABITACION_2010',
#  'DESHABITACION_2020',
#  'DIFPOP',
#  'DIFVIV',
#  'DIF_CPERC',
#  'DIF_DENSPOP',
#  'DIF_DENSVIV',
#  'DIF_DESHAB',
#  'DIF_EMP',
#  'DIF_HABXVIV',
# ...

# %% [markdown]
# #  Código para la elaboración de la ficha

# %% [markdown]
# ## Subida de datos

# %%
# Cargar la base de datos
loc = pd.read_excel(ruta_loc)
# mzn = pd.read_excel(ruta_mzn)
# mzn_prom_a = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_a')
# mzn_porc_a = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_a')
# mzn_cont_a = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_a')
# mzn_porc_cont_a = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_a')
# mzn_prom_b = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_b')
# mzn_porc_b = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_b')
# mzn_cont_b = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_b')
# mzn_porc_cont_b = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_b')
# mzn_prom_c = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_c')
# mzn_porc_c = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_c')
# mzn_cont_c = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_c')
# mzn_porc_cont_c = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_c')
# mzn_prom_d = pd.read_excel(ruta_mzn_prom,       'R_DESHAB_d')
# mzn_porc_d = pd.read_excel(ruta_mzn_porc,       'R_DESHAB_d')
# mzn_cont_d = pd.read_excel(ruta_mzn_cont,       'R_DESHAB_d')
# mzn_porc_cont_d = pd.read_excel(ruta_mzn_porc_cont,  'R_DESHAB_d')

# %% [markdown]
# ## Gráficas

# %%
#normal
def graficar_datos_resaltados(gdf, columna, cve_met_interes, output_path=None):
    # Extraer datos de la columna
    datos = gdf[columna].sort_values(ascending=False).reset_index(drop=True)
    media = datos.mean()
    
    # Identificar la posición de la metrópoli de interés
    valor_interes = gdf.loc[gdf['CVE_MET'] == cve_met_interes, columna].values[0]
    posicion_interes = datos[datos == valor_interes].index[0]
    
    # Crear la gráfica
    fig, ax = plt.subplots(figsize=(5.31, 3.06))  # Ajustar las proporciones
    ax.plot(range(len(datos)), datos, color="darkgray",linewidth=1.5, label="Datos")
    
    # Resaltar la posición de interés
    ax.scatter([posicion_interes], [valor_interes], color="blue", label=f'{cve_met_interes}', zorder=5)
    
    # Línea de la media
    ax.axhline(y=media, color="red", linestyle="--", linewidth=1.5, label="Media metropolitana")

    # Invertir el eje X
    ax.invert_xaxis()
    
    # Estilo
#    ax.set_title("Comparativa de Datos", fontsize=12, fontname="Century Gothic")
    ax.set_xlabel("Posición Nacional", fontsize=8, fontname="Century Gothic")
    ax.set_ylabel(columna, fontsize=8, fontname="Century Gothic")
    ax.tick_params(axis="both", labelsize=7)
    ax.legend(fontsize=8, loc="upper left")
    ax.set_xlim([len(datos) - 1, 0])
    
    # Guardar la gráfica si se especifica
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.close(fig)

    # if output_path:
    #     plt.savefig(output_path, dpi=300, bbox_inches="tight")
    # else:
    #     plt.show()




#Invertida
def graficar_datos_invertido(gdf, columna, cve_met_interes, output_path=None):
    # Extraer datos de la columna
    datos = gdf[columna].sort_values().reset_index(drop=True)
    media = datos.mean()

    # Identificar la posición de la metrópoli de interés
    valor_interes = gdf.loc[gdf['CVE_MET'] == cve_met_interes, columna].values[0]
    posicion_interes = datos[datos == valor_interes].index[0]
    
    # Crear la gráfica
    fig, ax = plt.subplots(figsize=(5.31, 3.06))  # Ajustar las proporciones
    ax.plot(range(len(datos)), datos, color="darkgray",linewidth=1.5, label="Datos")
    
    # Resaltar la posición de interés
    ax.scatter([posicion_interes], [valor_interes], color="blue", label=f'{cve_met_interes}', zorder=5)
    
    # Línea de la media
    ax.axhline(y=media, color="red", linestyle="--", linewidth=1.5, label="Media metropolitana")
    
    # Invertir ambos ejes
    ax.invert_yaxis()
    ax.invert_xaxis()
    
    # Estilo
#    ax.set_title("Comparativa de Datos", fontsize=12, fontname="Century Gothic")
    ax.set_xlabel("Posición Nacional", fontsize=8, fontname="Century Gothic")
    ax.set_ylabel(columna, fontsize=8, fontname="Century Gothic")
    ax.tick_params(axis="both", labelsize=7)
    ax.legend(fontsize=8, loc="upper left")
    ax.set_xlim([len(datos) - 1, 0])
    
    # Guardar la gráfica si se especifica
    plt.savefig(output_path, dpi=300, bbox_inches="tight")
    plt.close(fig)

    # if output_path:
    #     plt.savefig(output_path, dpi=300, bbox_inches="tight")
    # else:
    #     plt.show()

# %%
columnas = ['DENS_POP20', 'DENS_VIV20', 'DENS_EMP20', "DENS_UEC20",'DENS_EQ']
deshab = "DESHABITACION_2020"

# Obtener los valores únicos de CVE_MET
cves_met = loc['CVE_MET'].unique()

for cve_met_interes in cves_met:

    for columna in columnas:
        output_path = rf'Z:\VOCES\DATA\Tratados\NAC\FICHAS\Gráficas\{cve_met_interes}_{columna}.png'
        graficar_datos_resaltados(
            gdf=loc, 
            columna=columna, 
            cve_met_interes=cve_met_interes, 
            output_path=output_path
        )
    
    output_path = rf'Z:\VOCES\DATA\Tratados\NAC\FICHAS\Gráficas\{cve_met_interes}_{deshab}.png'
    graficar_datos_invertido(
    gdf=loc, 
    columna=deshab, 
    cve_met_interes=cve_met_interes, 
    output_path=output_path
    )

# %% [markdown]
# ## LLenado de Ficha

# %%
import pandas as pd
import openpyxl
from openpyxl import load_workbook
import shutil
import os
from openpyxl.drawing.image import Image

# %%
# Cargar las bases de datos
df_loc = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_LOC_NAC\estadísticas_bruto_metropoli.xlsx")

df_mzn_cont = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_gral\conteos.xlsx")
df_mzn_sum_cat = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_gral\sumas_categoria.xlsx")

df_mzn_por_sum_cat_a = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\por_sumas_categoria.xlsx", "R_DESHAB_a")
df_mzn_por_sum_cat_b = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\por_sumas_categoria.xlsx", "R_DESHAB_b")
df_mzn_por_sum_cat_c = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\por_sumas_categoria.xlsx", "R_DESHAB_c")
df_mzn_por_sum_cat_d = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_subt\por_sumas_categoria.xlsx", "R_DESHAB_d")

df_tip_por_sum_cat_dh = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\por_sumas_categoria.xlsx", "TIPOLOGIA_DH")
df_tip_por_cont_dh = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", "TIPOLOGIA_DH")

df_tip_por_cont_DH = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", 'TIPOLOGIA_DH')
df_tip_por_cont_A1 = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", 'TIPOLOGIA_A1')
df_tip_por_cont_A2 = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", 'TIPOLOGIA_A2')
df_tip_por_cont_A3 = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", 'TIPOLOGIA_A3')
df_tip_por_cont_B1 = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", 'TIPOLOGIA_B1')
df_tip_por_cont_B2 = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", 'TIPOLOGIA_B2')
df_tip_por_cont_B3 = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", 'TIPOLOGIA_B3')
df_tip_por_cont_B3_ = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\agrup_tip\porcentajes_conteos.xlsx", "TIPOLOGIA_B3_")

# df_loc = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_LOC_NAC\estadísticas_bruto_metropoli.xlsx")
# df_loc = pd.read_excel(r"Z:\VOCES\DATA\Tratados\NAC\INT_LOC_NAC\estadísticas_bruto_metropoli.xlsx")

df_conurba = pd.read_csv(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\gera\250508_Metro_Localidades rurales en proceso de conurbación.csv", encoding='latin1')
df_por_var = pd.read_csv(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\gera\250508_Metro_Variación Filtro POP y VIV.csv", encoding='latin1')
df_asteris = pd.read_csv(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\gera\250508_Metro_Porcentaje de error Astericos VIVPAR_DES.csv", encoding='latin1')
df_discont = pd.read_csv(r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\gera\250508_discontiguity_results.csv", encoding='utf-8-sig')

# Ruta a la plantilla original
template_path = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\FI_ME_molde.xlsx"

# Carpeta donde se guardarán las fichas
output_folder = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\Resultados"
os.makedirs(output_folder, exist_ok=True)

# Ruta donde están las gráficas
graf_folder = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\Gráficas"

# Ruta donde están las gráficas
m_res_folder = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\Cartografía\EU Residencial"
m_eco_folder = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\Cartografía\EU Económica"
m_eqp_folder = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\Cartografía\Cobertura de equipamiento"

# %% [markdown]
# ### Extracción de fuentes de molde

# %%
# Cargar el archivo y seleccionar la hoja activa (o una hoja por nombre)
wb = openpyxl.load_workbook(template_path)
ws = wb['Fuentes']  # O por nombre: ws = wb['NombreDeLaHoja']

# Recorrer todas las celdas con contenido y generar la salida
for row in ws.iter_rows(min_row=1, max_row=ws.max_row, min_col=1, max_col=ws.max_column):
    for cell in row:
        if cell.value is not None:
            print(f"ws['{cell.coordinate}'] = row['{cell.value}']")
# Out:
# ws['A1'] = row['CVE_MET']
# ws['E1'] = row['TIPO_MET']
# ws['I1'] = row['Ubicación Nacional']
# ws['L1'] = row['CVE_MET']
# ws['O1'] = row['NOM_MET']
# ws['A2'] = row['NOM_MET']
# ws['I2'] = row['Porcentaje de deshabitación']
# ws['L2'] = row['TIPO_MET']
# ws['L3'] = row['Unidades económicas y personal ocupado 2010 - 2020']
# ws['A4'] = row['Datos Generales']
# ws['A5'] = row['Indicadores obtenidos de las bases de datos por localidad de cada uno de los municipios de la metrópoli']
# ws['A6'] = row['Sobre la Metrópoli']
# ws['E6'] = row['Sobre la Metodología']
# ws['A7'] = row['Superficie (ha) 2020']
# ws['B7'] = row['area_ha']
# ws['C7'] = row['Núm. Manzanas 2020']
# ws['D7'] = row['=C94']
# ws['E7'] = row['Superficie residencial (ha)']
# ws['F7'] = row['area_ha']
# ws['G7'] = row['Proceso de conurbación']
# ws['H7'] = row['%area_ha']
# ws['A8'] = row['Núm. Localidades 2020']
# ws['B8'] = row['Localidades']
# ws['C8'] = row['Viv. por mil habitantes 2020']
# ...

# %%
# Cargar el archivo y seleccionar la hoja activa (o una hoja por nombre)
wb = openpyxl.load_workbook(template_path)
ws = wb['Fuentes']  # O por nombre: ws = wb['NombreDeLaHoja']

# Recorrer por columnas (columnas exteriores, filas interiores)
for col in ws.iter_cols(min_col=1, max_col=ws.max_column, min_row=1, max_row=ws.max_row):
    for cell in col:
        if cell.value is not None:
            print(f"ws['{cell.coordinate}'] = row['{cell.value}']")
# Out:
# ws['A1'] = row['CVE_MET']
# ws['A2'] = row['NOM_MET']
# ws['A4'] = row['Datos Generales']
# ws['A5'] = row['Indicadores obtenidos de las bases de datos por localidad de cada uno de los municipios de la metrópoli']
# ws['A6'] = row['Sobre la Metrópoli']
# ws['A7'] = row['Superficie (ha) 2020']
# ws['A8'] = row['Núm. Localidades 2020']
# ws['A9'] = row['Absolutos']
# ws['A10'] = row['Indicador']
# ws['A11'] = row['Población']
# ws['A12'] = row['Vivienda']
# ws['A13'] = row['Vivienda deshabitada']
# ws['A14'] = row['Cuartos']
# ws['A15'] = row['Unidades económicas']
# ws['A16'] = row['Empleos']
# ws['A17'] = row['Indicadores de deshabitación a nivel manzana']
# ws['A18'] = row['Indicadores obtenidos de las bases de datos por manzana de cada uno de los municipios de la metrópoli']
# ws['A19'] = row['*nota asteriscos']
# ws['A20'] = row['Vivienda y deshabitación 2010 - 2020']
# ws['A21'] = row['Indicador']
# ws['A23'] = row['Núm. viviendas deshabitadas 2020']
# ...

# %% [markdown]
# ### Creación y llenado DB Localidad

# %%
for index, row in df_loc.iterrows():
    # Crear una copia temporal de la plantilla para esta metrópoli
    temp_copy_path = os.path.join(output_folder, f"{row['CVE_MET']}.xlsx")
    shutil.copy(template_path, temp_copy_path)

    # Abrir el archivo recién copiado
    wb = load_workbook(temp_copy_path)
    ws = wb['Molde']

    ws.title = f"{row['CVE_MET']}"

    # Insertar datos en las celdas predefinidas
    #BD LOCALIDAD - AZUL
    ws['A1'] = row['CVE_MET']
    ws['E1'] = row['TIPO_MET']
    ws['A2'] = row['NOM_MET']

    ws['B7'] = row['area_ha']
    ws['B8'] = row['Localidades']
    
    ws['B11'] = row['POPTOT2010']
    ws['C11'] = row['POPTOT2020']
    ws['E11'] = row['DENS_POP10']
    ws['F11'] = row['DENS_POP20']
    ws['B12'] = row['VIVTOT2010']
    ws['C12'] = row['VIVTOT2020']
    ws['E12'] = row['DENS_VIV10']
    ws['F12'] = row['DENS_VIV20']
    ws['B13'] = row['VIVPAR_DES2010']
    ws['C13'] = row['VIVPAR_DES2020']
    ws['E13'] = row['DESHABITACION_2010']
    ws['F13'] = row['DESHABITACION_2020']
    ws['B14'] = row['CUARTOS2010']
    ws['C14'] = row['CUARTOS2020']
    ws['E14'] = row['CPERC2010']
    ws['F14'] = row['CPERC2020']
    ws['B15'] = row['UE_10']
    ws['C15'] = row['UE_20']
    ws['E15'] = row['DENS_UEC10']
    ws['F15'] = row['DENS_UEC20']
    ws['B16'] = row['Emp_10']
    ws['C16'] = row['Emp_20']
    ws['E16'] = row['DENS_EMP10']
    ws['F16'] = row['DENS_EMP20']
    
    ws['I49'] = row['DENS_EQ']

    ws['A50'] = row['CVE_MET']
    ws['D50'] = row['NOM_MET']
    ws['A51'] = row['TIPO_MET']

    ws['L1'] = row['CVE_MET']
    ws['O1'] = row['NOM_MET']
    ws['L2'] = row['TIPO_MET']

    ws['L50'] = row['CVE_MET']
    ws['O50'] = row['NOM_MET']
    ws['L51'] = row['TIPO_MET']

    # Guardar el archivo modificado
    wb.save(temp_copy_path)

# %% [markdown]
# ### Llenado DB Gera

# %%
#conurbación

for index, row in df_conurba.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['H7'] = row['%area_ha']

    # Guardar el archivo actualizado
    wb.save(file_path)

print("Indicador conurbación insertado correctamente.")
# Out:
# Indicador conurbación insertado correctamente.

# %%
#porcentaje variación

for index, row in df_por_var.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['F7'] = row['Fil_area_ha']
    ws['F8'] = row['%p20_filtro']
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("Indicadores porcentaje de variación insertados correctamente.")
# Out:
# Indicadores porcentaje de variación insertados correctamente.

# %%
#asteriscos

for index, row in df_asteris.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['H19'] = row['Vloc/Vmza (Error voces)']
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("Indicador asteriscos insertados correctamente.")
# Out:
# Indicador asteriscos insertados correctamente.

# %%
#discontinuidad

for index, row in df_discont.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['H8'] = row['Discontiguity_Index']
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("Indicador discontinuidad insertados correctamente.")
# Out:
# Indicador discontinuidad insertados correctamente.

# %% [markdown]
# ### Llenado DB Viviendas

# %%
#deshab_dh

for index, row in df_tip_por_sum_cat_dh.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['E24'] = row['TIPOLOGIA_DH_VIVPAR_DES2020']
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de vivienda (dh) insertados correctamente.")
# Out:
# porcentajes de vivienda (dh) insertados correctamente.

# %%
#deshab_a

for index, row in df_mzn_por_sum_cat_a.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['E25'] = row['TIPOLOGIA_A1_VIVPAR_DES2020']
    ws['E26'] = row['TIPOLOGIA_A2_VIVPAR_DES2020']
    ws['E27'] = row['TIPOLOGIA_A3_VIVPAR_DES2020']
    ws['E28'] = row['TIPOLOGIA_B1_VIVPAR_DES2020']
    ws['E29'] = row['TIPOLOGIA_B2_VIVPAR_DES2020']
    ws['E30'] = row['TIPOLOGIA_B3_VIVPAR_DES2020']
    ws['E31'] = row["TIPOLOGIA_B3'_VIVPAR_DES2020"]

    ws['E35'] = row['TIPOLOGIA_ue_A1_VIVPAR_DES2020']
    ws['E36'] = row['TIPOLOGIA_ue_A2_VIVPAR_DES2020']
    ws['E37'] = row['TIPOLOGIA_ue_B1_VIVPAR_DES2020']
    ws['E38'] = row['TIPOLOGIA_ue_B2_VIVPAR_DES2020']
    ws['E39'] = row['TIPOLOGIA_ue_C1_VIVPAR_DES2020']
    ws['E40'] = row['TIPOLOGIA_ue_C2_VIVPAR_DES2020']
 
    ws['E44'] = row['CVE_EQ_C_A_VIVPAR_DES2020']
    ws['E45'] = row['CVE_EQ_C_B_VIVPAR_DES2020']
    ws['E46'] = row['CVE_EQ_C_C_VIVPAR_DES2020']
    ws['E47'] = row['CVE_EQ_C_D_VIVPAR_DES2020']
    ws['E48'] = row['CVE_EQ_C_E_VIVPAR_DES2020']
    # ws['E49'] = row['CVE_EQ_C_F_VIVPAR_DES2020']    
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de vivienda (deshab_a) insertados correctamente.")
# Out:
# porcentajes de vivienda (deshab_a) insertados correctamente.

# %%
#deshab_b

for index, row in df_mzn_por_sum_cat_b.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['F25'] = row['TIPOLOGIA_A1_VIVPAR_DES2020']
    ws['F26'] = row['TIPOLOGIA_A2_VIVPAR_DES2020']
    ws['F27'] = row['TIPOLOGIA_A3_VIVPAR_DES2020']
    ws['F28'] = row['TIPOLOGIA_B1_VIVPAR_DES2020']
    ws['F29'] = row['TIPOLOGIA_B2_VIVPAR_DES2020']
    ws['F30'] = row['TIPOLOGIA_B3_VIVPAR_DES2020']
    ws['F31'] = row["TIPOLOGIA_B3'_VIVPAR_DES2020"]

    ws['F35'] = row['TIPOLOGIA_ue_A1_VIVPAR_DES2020']
    ws['F36'] = row['TIPOLOGIA_ue_A2_VIVPAR_DES2020']
    ws['F37'] = row['TIPOLOGIA_ue_B1_VIVPAR_DES2020']
    ws['F38'] = row['TIPOLOGIA_ue_B2_VIVPAR_DES2020']
    ws['F39'] = row['TIPOLOGIA_ue_C1_VIVPAR_DES2020']
    ws['F40'] = row['TIPOLOGIA_ue_C2_VIVPAR_DES2020']
    
    ws['F44'] = row['CVE_EQ_C_A_VIVPAR_DES2020']
    ws['F45'] = row['CVE_EQ_C_B_VIVPAR_DES2020']
    ws['F46'] = row['CVE_EQ_C_C_VIVPAR_DES2020']
    ws['F47'] = row['CVE_EQ_C_D_VIVPAR_DES2020']
    ws['F48'] = row['CVE_EQ_C_E_VIVPAR_DES2020']
    # ws['F49'] = row['CVE_EQ_C_F_VIVPAR_DES2020']
 
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de vivienda (deshab_b) insertados correctamente.")
# Out:
# porcentajes de vivienda (deshab_b) insertados correctamente.

# %%
#deshab_c

for index, row in df_mzn_por_sum_cat_c.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['G25'] = row['TIPOLOGIA_A1_VIVPAR_DES2020']
    ws['G26'] = row['TIPOLOGIA_A2_VIVPAR_DES2020']
    ws['G27'] = row['TIPOLOGIA_A3_VIVPAR_DES2020']
    ws['G28'] = row['TIPOLOGIA_B1_VIVPAR_DES2020']
    ws['G29'] = row['TIPOLOGIA_B2_VIVPAR_DES2020']
    ws['G30'] = row['TIPOLOGIA_B3_VIVPAR_DES2020']
    ws['G31'] = row["TIPOLOGIA_B3'_VIVPAR_DES2020"]

    ws['G35'] = row['TIPOLOGIA_ue_A1_VIVPAR_DES2020']
    ws['G36'] = row['TIPOLOGIA_ue_A2_VIVPAR_DES2020']
    ws['G37'] = row['TIPOLOGIA_ue_B1_VIVPAR_DES2020']
    ws['G38'] = row['TIPOLOGIA_ue_B2_VIVPAR_DES2020']
    ws['G39'] = row['TIPOLOGIA_ue_C1_VIVPAR_DES2020']
    ws['G40'] = row['TIPOLOGIA_ue_C2_VIVPAR_DES2020'] 
   
    ws['G44'] = row['CVE_EQ_C_A_VIVPAR_DES2020']
    ws['G45'] = row['CVE_EQ_C_B_VIVPAR_DES2020']
    ws['G46'] = row['CVE_EQ_C_C_VIVPAR_DES2020']
    ws['G47'] = row['CVE_EQ_C_D_VIVPAR_DES2020']
    ws['G48'] = row['CVE_EQ_C_E_VIVPAR_DES2020']
    # ws['G49'] = row['CVE_EQ_C_F_VIVPAR_DES2020']
 
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de vivienda (deshab_c) insertados correctamente.")
# Out:
# porcentajes de vivienda (deshab_c) insertados correctamente.

# %%
#deshab_d

for index, row in df_mzn_por_sum_cat_d.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['H25'] = row['TIPOLOGIA_A1_VIVPAR_DES2020']
    ws['H26'] = row['TIPOLOGIA_A2_VIVPAR_DES2020']
    ws['H27'] = row['TIPOLOGIA_A3_VIVPAR_DES2020']
    ws['H28'] = row['TIPOLOGIA_B1_VIVPAR_DES2020']
    ws['H29'] = row['TIPOLOGIA_B2_VIVPAR_DES2020']
    ws['H30'] = row['TIPOLOGIA_B3_VIVPAR_DES2020']
    ws['H31'] = row["TIPOLOGIA_B3'_VIVPAR_DES2020"]
    
    ws['H35'] = row['TIPOLOGIA_ue_A1_VIVPAR_DES2020']
    ws['H36'] = row['TIPOLOGIA_ue_A2_VIVPAR_DES2020']
    ws['H37'] = row['TIPOLOGIA_ue_B1_VIVPAR_DES2020']
    ws['H38'] = row['TIPOLOGIA_ue_B2_VIVPAR_DES2020']
    ws['H39'] = row['TIPOLOGIA_ue_C1_VIVPAR_DES2020']
    ws['H40'] = row['TIPOLOGIA_ue_C2_VIVPAR_DES2020']
   
    ws['H44'] = row['CVE_EQ_C_A_VIVPAR_DES2020']
    ws['H45'] = row['CVE_EQ_C_B_VIVPAR_DES2020']
    ws['H46'] = row['CVE_EQ_C_C_VIVPAR_DES2020']
    ws['H47'] = row['CVE_EQ_C_D_VIVPAR_DES2020']
    ws['H48'] = row['CVE_EQ_C_E_VIVPAR_DES2020']
    # ws['H49'] = row['CVE_EQ_C_F_VIVPAR_DES2020']
 
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de vivienda (deshab_d) insertados correctamente.")
# Out:
# porcentajes de vivienda (deshab_d) insertados correctamente.

# %%
#Ind vivienda - gral

for index, row in df_mzn_sum_cat.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['E23'] = row['R_DESHAB_a_VIVPAR_DES2020']
    ws['F23'] = row['R_DESHAB_b_VIVPAR_DES2020']
    ws['G23'] = row['R_DESHAB_c_VIVPAR_DES2020']
    ws['H23'] = row['R_DESHAB_d_VIVPAR_DES2020']
 
    ws['D24'] = row['TIPOLOGIA_DH_VIVPAR_DES2020']
    ws['D25'] = row['TIPOLOGIA_A1_VIVPAR_DES2020']
    ws['D26'] = row['TIPOLOGIA_A2_VIVPAR_DES2020']
    ws['D27'] = row['TIPOLOGIA_A3_VIVPAR_DES2020']
    ws['D28'] = row['TIPOLOGIA_B1_VIVPAR_DES2020']
    ws['D29'] = row['TIPOLOGIA_B2_VIVPAR_DES2020']
    ws['D30'] = row['TIPOLOGIA_B3_VIVPAR_DES2020']
    ws['D31'] = row["TIPOLOGIA_B3'_VIVPAR_DES2020"]

    ws['D35'] = row['TIPOLOGIA_ue_A1_VIVPAR_DES2020']
    ws['D36'] = row['TIPOLOGIA_ue_A2_VIVPAR_DES2020']
    ws['D37'] = row['TIPOLOGIA_ue_B1_VIVPAR_DES2020']
    ws['D38'] = row['TIPOLOGIA_ue_B2_VIVPAR_DES2020']
    ws['D39'] = row['TIPOLOGIA_ue_C1_VIVPAR_DES2020']
    ws['D40'] = row['TIPOLOGIA_ue_C2_VIVPAR_DES2020']
    
    ws['D44'] = row['CVE_EQ_C_A_VIVPAR_DES2020']
    ws['D45'] = row['CVE_EQ_C_B_VIVPAR_DES2020']
    ws['D46'] = row['CVE_EQ_C_C_VIVPAR_DES2020']
    ws['D47'] = row['CVE_EQ_C_D_VIVPAR_DES2020']
    ws['D48'] = row['CVE_EQ_C_E_VIVPAR_DES2020']
    # ws['D49'] = row['CVE_EQ_C_F_VIVPAR_DES2020']
 
    # Guardar el archivo actualizado
    wb.save(file_path)

print("números de vivienda insertados correctamente.")
# Out:
# números de vivienda insertados correctamente.

# %% [markdown]
# ### Llenado DB Manzanas

# %%
#Ind Manzana - gral

for index, row in df_mzn_cont.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['C95'] = row['R_DESHAB_a']
    ws['C96'] = row['R_DESHAB_b']
    ws['C97'] = row['R_DESHAB_c']
    ws['C98'] = row['R_DESHAB_d']
    
    ws['D94'] = row['TIPOLOGIA_DH']
    ws['E94'] = row['TIPOLOGIA_A1']
    ws['F94'] = row['TIPOLOGIA_A2']
    ws['G94'] = row['TIPOLOGIA_A3']
    ws['H94'] = row['TIPOLOGIA_B1']
    ws['I94'] = row['TIPOLOGIA_B2']
    ws['J94'] = row['TIPOLOGIA_B3']
    ws['K94'] = row["TIPOLOGIA_B3'"]

    ws['N44'] = row['TIPOLOGIA_ue_A1']
    ws['N45'] = row['TIPOLOGIA_ue_A2']
    ws['N46'] = row['TIPOLOGIA_ue_B1']
    ws['N47'] = row['TIPOLOGIA_ue_B2']
    ws['N48'] = row['TIPOLOGIA_ue_C1']
    ws['N49'] = row['TIPOLOGIA_ue_C2']
    
    ws['N93'] = row['CVE_EQ_C_A']
    ws['N94'] = row['CVE_EQ_C_B']
    ws['N95'] = row['CVE_EQ_C_C']
    ws['N96'] = row['CVE_EQ_C_D']
    ws['N97'] = row['CVE_EQ_C_E']
    # ws['N98'] = row['CVE_EQ_C_F']
 
    # Guardar el archivo actualizado
    wb.save(file_path)

print("números de manzanas insertados correctamente.")
# Out:
# números de manzanas insertados correctamente.

# %%
#manzanas_dh

for index, row in df_tip_por_cont_dh.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['D95'] = row['TIPOLOGIA_DH']
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (dh) insertados correctamente.")
# Out:
# porcentajes de manzanas (dh) insertados correctamente.

# %%
#Ind Porcentajes Manzana - DH

for index, row in df_tip_por_cont_DH.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    # ws['D95'] = row['R_DESHAB_a']
    # ws['D96'] = row['R_DESHAB_b']
    # ws['D97'] = row['R_DESHAB_c']
    # ws['D98'] = row['R_DESHAB_d']

    ws['O44'] = row['TIPOLOGIA_ue_A1']
    ws['O45'] = row['TIPOLOGIA_ue_A2']
    ws['O46'] = row['TIPOLOGIA_ue_B1']
    ws['O47'] = row['TIPOLOGIA_ue_B2']
    ws['O48'] = row['TIPOLOGIA_ue_C1']
    ws['O49'] = row['TIPOLOGIA_ue_C2']

    ws['O93'] = row['CVE_EQ_C_A']
    ws['O94'] = row['CVE_EQ_C_B']
    ws['O95'] = row['CVE_EQ_C_C']
    ws['O96'] = row['CVE_EQ_C_D']
    ws['O97'] = row['CVE_EQ_C_E']
    # ws['O98'] = row['CVE_EQ_C_F'] 
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (DH) insertados correctamente.")
# Out:
# porcentajes de manzanas (DH) insertados correctamente.

# %%
#Ind Porcentajes Manzana - A1

for index, row in df_tip_por_cont_A1.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['E95'] = row['R_DESHAB_a']
    ws['E96'] = row['R_DESHAB_b']
    ws['E97'] = row['R_DESHAB_c']
    ws['E98'] = row['R_DESHAB_d']

    ws['P44'] = row['TIPOLOGIA_ue_A1']
    ws['P45'] = row['TIPOLOGIA_ue_A2']
    ws['P46'] = row['TIPOLOGIA_ue_B1']
    ws['P47'] = row['TIPOLOGIA_ue_B2']
    ws['P48'] = row['TIPOLOGIA_ue_C1']
    ws['P49'] = row['TIPOLOGIA_ue_C2']

    ws['P93'] = row['CVE_EQ_C_A']
    ws['P94'] = row['CVE_EQ_C_B']
    ws['P95'] = row['CVE_EQ_C_C']
    ws['P96'] = row['CVE_EQ_C_D']
    ws['P97'] = row['CVE_EQ_C_E']
    # ws['P98'] = row['CVE_EQ_C_F'] 
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (A1) insertados correctamente.")
# Out:
# porcentajes de manzanas (A1) insertados correctamente.

# %%
#Ind Porcentajes Manzana - A2

for index, row in df_tip_por_cont_A2.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['F95'] = row['R_DESHAB_a']
    ws['F96'] = row['R_DESHAB_b']
    ws['F97'] = row['R_DESHAB_c']
    ws['F98'] = row['R_DESHAB_d']

    ws['Q44'] = row['TIPOLOGIA_ue_A1']
    ws['Q45'] = row['TIPOLOGIA_ue_A2']
    ws['Q46'] = row['TIPOLOGIA_ue_B1']
    ws['Q47'] = row['TIPOLOGIA_ue_B2']
    ws['Q48'] = row['TIPOLOGIA_ue_C1']
    ws['Q49'] = row['TIPOLOGIA_ue_C2']

    ws['Q93'] = row['CVE_EQ_C_A']
    ws['Q94'] = row['CVE_EQ_C_B']
    ws['Q95'] = row['CVE_EQ_C_C']
    ws['Q96'] = row['CVE_EQ_C_D']
    ws['Q97'] = row['CVE_EQ_C_E']
    # ws['Q98'] = row['CVE_EQ_C_F']
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (A2) insertados correctamente.")
# Out:
# porcentajes de manzanas (A2) insertados correctamente.

# %%
#Ind Porcentajes Manzana - A3

for index, row in df_tip_por_cont_A3.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['G95'] = row['R_DESHAB_a']
    ws['G96'] = row['R_DESHAB_b']
    ws['G97'] = row['R_DESHAB_c']
    ws['G98'] = row['R_DESHAB_d']
    
    ws['R44'] = row['TIPOLOGIA_ue_A1']
    ws['R45'] = row['TIPOLOGIA_ue_A2']
    ws['R46'] = row['TIPOLOGIA_ue_B1']
    ws['R47'] = row['TIPOLOGIA_ue_B2']
    ws['R48'] = row['TIPOLOGIA_ue_C1']
    ws['R49'] = row['TIPOLOGIA_ue_C2']

    ws['R93'] = row['CVE_EQ_C_A']
    ws['R94'] = row['CVE_EQ_C_B']
    ws['R95'] = row['CVE_EQ_C_C']
    ws['R96'] = row['CVE_EQ_C_D']
    ws['R97'] = row['CVE_EQ_C_E']
    # ws['R98'] = row['CVE_EQ_C_F'] 
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (A3) insertados correctamente.")
# Out:
# porcentajes de manzanas (A3) insertados correctamente.

# %%
#Ind Porcentajes Manzana - B1

for index, row in df_tip_por_cont_B1.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['H95'] = row['R_DESHAB_a']
    ws['H96'] = row['R_DESHAB_b']
    ws['H97'] = row['R_DESHAB_c']
    ws['H98'] = row['R_DESHAB_d']

    ws['S44'] = row['TIPOLOGIA_ue_A1']
    ws['S45'] = row['TIPOLOGIA_ue_A2']
    ws['S46'] = row['TIPOLOGIA_ue_B1']
    ws['S47'] = row['TIPOLOGIA_ue_B2']
    ws['S48'] = row['TIPOLOGIA_ue_C1']
    ws['S49'] = row['TIPOLOGIA_ue_C2']

    ws['S93'] = row['CVE_EQ_C_A']
    ws['S94'] = row['CVE_EQ_C_B']
    ws['S95'] = row['CVE_EQ_C_C']
    ws['S96'] = row['CVE_EQ_C_D']
    ws['S97'] = row['CVE_EQ_C_E']
    # ws['S98'] = row['CVE_EQ_C_F'] 
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (B1) insertados correctamente.")
# Out:
# porcentajes de manzanas (B1) insertados correctamente.

# %%
#Ind Porcentajes Manzana - B2

for index, row in df_tip_por_cont_B2.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['I95'] = row['R_DESHAB_a']
    ws['I96'] = row['R_DESHAB_b']
    ws['I97'] = row['R_DESHAB_c']
    ws['I98'] = row['R_DESHAB_d']

    ws['T44'] = row['TIPOLOGIA_ue_A1']
    ws['T45'] = row['TIPOLOGIA_ue_A2']
    ws['T46'] = row['TIPOLOGIA_ue_B1']
    ws['T47'] = row['TIPOLOGIA_ue_B2']
    ws['T48'] = row['TIPOLOGIA_ue_C1']
    ws['T49'] = row['TIPOLOGIA_ue_C2']

    ws['T93'] = row['CVE_EQ_C_A']
    ws['T94'] = row['CVE_EQ_C_B']
    ws['T95'] = row['CVE_EQ_C_C']
    ws['T96'] = row['CVE_EQ_C_D']
    ws['T97'] = row['CVE_EQ_C_E']
    # ws['T98'] = row['CVE_EQ_C_F'] 
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (B2) insertados correctamente.")
# Out:
# porcentajes de manzanas (B2) insertados correctamente.

# %%
#Ind Porcentajes Manzana - B3

for index, row in df_tip_por_cont_B3.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['J95'] = row['R_DESHAB_a']
    ws['J96'] = row['R_DESHAB_b']
    ws['J97'] = row['R_DESHAB_c']
    ws['J98'] = row['R_DESHAB_d']
    
    ws['U44'] = row['TIPOLOGIA_ue_A1']
    ws['U45'] = row['TIPOLOGIA_ue_A2']
    ws['U46'] = row['TIPOLOGIA_ue_B1']
    ws['U47'] = row['TIPOLOGIA_ue_B2']
    ws['U48'] = row['TIPOLOGIA_ue_C1']
    ws['U49'] = row['TIPOLOGIA_ue_C2']

    ws['U93'] = row['CVE_EQ_C_A']
    ws['U94'] = row['CVE_EQ_C_B']
    ws['U95'] = row['CVE_EQ_C_C']
    ws['U96'] = row['CVE_EQ_C_D']
    ws['U97'] = row['CVE_EQ_C_E']
    # ws['U98'] = row['CVE_EQ_C_F']
     
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (B3) insertados correctamente.")
# Out:
# porcentajes de manzanas (B3) insertados correctamente.

# %%
#Ind Porcentajes Manzana - B3'

for index, row in df_tip_por_cont_B3_.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")

    # Verifica si el archivo existe
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abrir el archivo existente
    wb = load_workbook(file_path)

    # Usar nombre de hoja si sabes cuál es
    # Por ejemplo, si la hoja se renombró como el CVE_MET:
    ws = wb[cve_met]

    # Rellenar nuevas celdas (especifica tus nuevas columnas aquí)
    ws['K95'] = row['R_DESHAB_a']
    ws['K96'] = row['R_DESHAB_b']
    ws['K97'] = row['R_DESHAB_c']
    ws['K98'] = row['R_DESHAB_d']

    ws['V44'] = row['TIPOLOGIA_ue_A1']
    ws['V45'] = row['TIPOLOGIA_ue_A2']
    ws['V46'] = row['TIPOLOGIA_ue_B1']
    ws['V47'] = row['TIPOLOGIA_ue_B2']
    ws['V48'] = row['TIPOLOGIA_ue_C1']
    ws['V49'] = row['TIPOLOGIA_ue_C2']

    ws['V93'] = row['CVE_EQ_C_A']
    ws['V94'] = row['CVE_EQ_C_B']
    ws['V95'] = row['CVE_EQ_C_C']
    ws['V96'] = row['CVE_EQ_C_D']
    ws['V97'] = row['CVE_EQ_C_E']
    # ws['V98'] = row['CVE_EQ_C_F'] 
    
    # Guardar el archivo actualizado
    wb.save(file_path)

print("porcentajes de manzanas (B3') insertados correctamente.")
# Out:
# porcentajes de manzanas (B3') insertados correctamente.

# %% [markdown]
# ### Llenado Imágenes

# %%
# Imágenes pequeñas: 5.4 x 3.3 cm
# img_peq_w, img_peq_h = 204, 125
img_peq_w, img_peq_h = 204, 125

# Imágenes grandes: 19.8 x 20.35 cm
# img_gran_w, img_gran_h = 748, 769
img_gran_w, img_gran_h = 744, 769

# Función para insertar imágenes dadas las rutas y celdas destino
def insertar_imagenes(file_path, hoja, imagenes_celdas, ancho_px, alto_px):
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        return

    wb = load_workbook(file_path)
    ws = wb[hoja]

    for ruta_img, celda in imagenes_celdas:
        if not os.path.exists(ruta_img):
            print(f"Imagen no encontrada: {ruta_img}")
            continue
        img = Image(ruta_img)
        img.width = ancho_px
        img.height = alto_px
        ws.add_image(img, celda)

    wb.save(file_path)

for _, row in df_loc.iterrows():
    cve_met = row['CVE_MET']
    file_path = os.path.join(output_folder, f"{cve_met}.xlsx")
    hoja = cve_met

    # Imágenes pequeñas (gráficas de densidades)
    imagenes_pequenas = [
        (os.path.join(graf_folder, f"{cve_met}_DESHABITACION_2020.png"), 'I3'),
        (os.path.join(graf_folder, f"{cve_met}_DENS_POP20.png"),          'I11'),
        (os.path.join(graf_folder, f"{cve_met}_DENS_VIV20.png"),          'I19'),
        (os.path.join(graf_folder, f"{cve_met}_DENS_EMP20.png"),          'I27'),
        (os.path.join(graf_folder, f"{cve_met}_DENS_UEC20.png"),          'I35'),
        (os.path.join(graf_folder, f"{cve_met}_DENS_EQ.png"),             'I43'),
    ]
    insertar_imagenes(file_path, hoja, imagenes_pequenas, img_peq_w, img_peq_h)

    # Imágenes grandes (mapas)
    imagenes_grandes = [
        (os.path.join(m_res_folder, f"{cve_met}.png"), 'A53'),
        (os.path.join(m_eco_folder, f"{cve_met}.png"), 'L4'),
        (os.path.join(m_eqp_folder, f"{cve_met}.png"), 'L53'),
    ]
    insertar_imagenes(file_path, hoja, imagenes_grandes, img_gran_w, img_gran_h)

print("Imágenes insertadas correctamente.")
# Out:
# Imágenes insertadas correctamente.

# %% [markdown]
# ## Exportar fichas

# %%
import os
import pandas as pd
import win32com.client as win32

# Ruta de entrada y salida
input_folder = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\Resultados"
output_folder = r"Z:\VOCES\DATA\Tratados\NAC\FICHAS\PDFs"
os.makedirs(output_folder, exist_ok=True)

# Itera sobre el dataframe
for index, row in df_loc.iterrows():
    cve_met = row["CVE_MET"]
    file_path = os.path.join(input_folder, f"{cve_met}.xlsx")
    output_pdf = os.path.join(output_folder, f"{cve_met}.pdf")

    # Verifica que el archivo exista
    if not os.path.exists(file_path):
        print(f"Archivo no encontrado: {file_path}")
        continue

    # Abre Excel con COM
    excel = win32.gencache.EnsureDispatch('Excel.Application')
    wb = excel.Workbooks.Open(file_path)

    try:
        # Exporta a PDF (puedes ajustar el índice de la hoja o usar el nombre si es necesario)
        wb.ExportAsFixedFormat(0, output_pdf)  # 0 = PDF format
        print(f"{cve_met} exportado correctamente.")
    except Exception as e:
        print(f"Error al exportar {cve_met}: {e}")
    finally:
        wb.Close(False)

    excel.Quit()

print("Exportación a PDF completada.")
# Out:
# 01.1.01 exportado correctamente.
# 02.1.01 exportado correctamente.
# 02.2.02 exportado correctamente.
# 02.2.03 exportado correctamente.
# 03.2.01 exportado correctamente.
# 03.2.02 exportado correctamente.
# 04.2.01 exportado correctamente.
# 05.1.01 exportado correctamente.
# 05.1.02 exportado correctamente.
# 05.1.03 exportado correctamente.
# 05.1.04 exportado correctamente.
# 05.3.05 exportado correctamente.
# 06.1.01 exportado correctamente.
# 06.3.02 exportado correctamente.
# 07.1.01 exportado correctamente.
# 07.1.02 exportado correctamente.
# 08.1.01 exportado correctamente.
# 08.1.02 exportado correctamente.
# 08.2.03 exportado correctamente.
# 08.3.04 exportado correctamente.
# 09.1.01 exportado correctamente.
# 10.2.01 exportado correctamente.
# 11.1.01 exportado correctamente.
# 11.1.02 exportado correctamente.
# 11.2.03 exportado correctamente.
# 11.2.04 exportado correctamente.
# 11.3.05 exportado correctamente.
# 11.3.06 exportado correctamente.
# ...
