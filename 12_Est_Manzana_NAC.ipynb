# %%
import pandas as pd
import geopandas as gpd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Cargar el archivo de manzanas
MAPA_ruta = r"Z:\VOCES\DATA\Tratados\NAC\INT_MZN_NAC\Mzn_Tipologías_NAC_ImpEq.gpkg"

MAPA_df = gpd.read_file(MAPA_ruta, layer='Mzn_Subtipologias_UeEq_filtrado')

# Separar por Tipología
tipologias = MAPA_df['TIPOLOGIA'].unique()

# Diccionario para almacenar resultados
correlaciones = {}

# Calcular correlación para cada tipología
for tipologia in tipologias:
    df_tipologia = MAPA_df[MAPA_df['TIPOLOGIA'] == tipologia]
    correlacion = df_tipologia[['POPTOT2020', 'VIVTOT2020']].corr(method='pearson')
    correlaciones[tipologia] = correlacion
    print(f"Correlación en {tipologia}:")
    print(correlacion)
    print("\n")

# Visualizar correlaciones como mapa de calor para cada tipología
for tipologia, correlacion in correlaciones.items():
    sns.heatmap(correlacion, annot=True, cmap='coolwarm')
    plt.title(f'Correlación Población y Vivienda en {tipologia}')
    plt.show()
# Out:
# Correlación en B3:
#             POPTOT2020  VIVTOT2020
# POPTOT2020    1.000000    0.950134
# VIVTOT2020    0.950134    1.000000
#
#
# Correlación en A1:
#             POPTOT2020  VIVTOT2020
# POPTOT2020     1.00000     0.95161
# VIVTOT2020     0.95161     1.00000
#
#
# Correlación en A3:
#             POPTOT2020  VIVTOT2020
# POPTOT2020    1.000000    0.927071
# VIVTOT2020    0.927071    1.000000
#
#
# Correlación en A2:
#             POPTOT2020  VIVTOT2020
# POPTOT2020    1.000000    0.956923
# VIVTOT2020    0.956923    1.000000
#
#
# Correlación en B2:
#             POPTOT2020  VIVTOT2020
# POPTOT2020    1.000000    0.929456
# VIVTOT2020    0.929456    1.000000
#
#
# Correlación en B3':
#             POPTOT2020  VIVTOT2020
# POPTOT2020    1.000000    0.737964
# VIVTOT2020    0.737964    1.000000
#
#
# Correlación en B1:
#             POPTOT2020  VIVTOT2020
# POPTOT2020    1.000000    0.765981
# VIVTOT2020    0.765981    1.000000
#
#
# Correlación en DH:
#             POPTOT2020  VIVTOT2020
# POPTOT2020         NaN         NaN
# VIVTOT2020         NaN         1.0

# %%
import statsmodels.api as sm

# Realizar regresión lineal para cada tipología
for tipologia in tipologias:
    df_tipologia = MAPA_df[MAPA_df['TIPOLOGIA'] == tipologia]
    
    # Variables independiente y dependiente
    X = df_tipologia['VIVTOT2020']
    y = df_tipologia['POPTOT2020']
    
    # Añadir constante para el intercepto
    X = sm.add_constant(X)
    
    # Ajustar el modelo
    model = sm.OLS(y, X).fit()
    
    # Mostrar resumen
    print(f"Resultados de Regresión en {tipologia}:")
    print(model.summary())
    print("\n")
# Out:
# Resultados de Regresión en B3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                       0.903
# Model:                            OLS   Adj. R-squared:                  0.903
# Method:                 Least Squares   F-statistic:                 2.065e+06
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        07:26:39   Log-Likelihood:            -1.1799e+06
# No. Observations:              222489   AIC:                         2.360e+06
# Df Residuals:                  222487   BIC:                         2.360e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         14.0475      0.119    117.717      0.000      13.814      14.281
# VIVTOT2020     2.6494      0.002   1437.146      0.000       2.646       2.653
# ==============================================================================
# Omnibus:                   384094.136   Durbin-Watson:                   1.512
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       5083027922.711
# Skew:                         -11.078   Prob(JB):                         0.00
# Kurtosis:                     743.147   Cond. No.                         74.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Resultados de Regresión en A1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                       0.906
# Model:                            OLS   Adj. R-squared:                  0.906
# Method:                 Least Squares   F-statistic:                 9.742e+05
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        07:26:40   Log-Likelihood:            -4.7713e+05
# No. Observations:              101599   AIC:                         9.543e+05
# Df Residuals:                  101597   BIC:                         9.543e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.3655      0.112     -3.263      0.001      -0.585      -0.146
# VIVTOT2020     3.0775      0.003    987.022      0.000       3.071       3.084
# ==============================================================================
# Omnibus:                   110397.564   Durbin-Watson:                   1.463
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        596515997.302
# Skew:                          -4.188   Prob(JB):                         0.00
# Kurtosis:                     378.287   Cond. No.                         48.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Resultados de Regresión en A3:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                       0.859
# Model:                            OLS   Adj. R-squared:                  0.859
# Method:                 Least Squares   F-statistic:                 5.106e+05
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        07:26:40   Log-Likelihood:            -4.0614e+05
# No. Observations:               83495   AIC:                         8.123e+05
# Df Residuals:                   83493   BIC:                         8.123e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.8363      0.149     19.067      0.000       2.545       3.128
# VIVTOT2020     2.6017      0.004    714.560      0.000       2.595       2.609
# ==============================================================================
# Omnibus:                   178168.344   Durbin-Watson:                   1.536
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):       8070338127.691
# Skew:                         -17.877   Prob(JB):                         0.00
# Kurtosis:                    1525.655   Cond. No.                         56.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Resultados de Regresión en A2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                       0.916
# Model:                            OLS   Adj. R-squared:                  0.916
# Method:                 Least Squares   F-statistic:                 1.889e+06
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        07:26:40   Log-Likelihood:            -8.1735e+05
# No. Observations:              173894   AIC:                         1.635e+06
# Df Residuals:                  173892   BIC:                         1.635e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.2170      0.090     24.556      0.000       2.040       2.394
# VIVTOT2020     2.7994      0.002   1374.385      0.000       2.795       2.803
# ==============================================================================
# Omnibus:                   166313.648   Durbin-Watson:                   1.386
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):        281671546.483
# Skew:                          -3.485   Prob(JB):                         0.00
# Kurtosis:                     200.044   Cond. No.                         62.7
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Resultados de Regresión en B2:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                       0.864
# Model:                            OLS   Adj. R-squared:                  0.864
# Method:                 Least Squares   F-statistic:                 8.977e+05
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        07:26:41   Log-Likelihood:            -7.3076e+05
# No. Observations:              141440   AIC:                         1.462e+06
# Df Residuals:                  141438   BIC:                         1.462e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.4955      0.144     93.685      0.000      13.213      13.778
# VIVTOT2020     2.6254      0.003    947.466      0.000       2.620       2.631
# ==============================================================================
# Omnibus:                   335069.686   Durbin-Watson:                   1.570
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     127965934376.334
# Skew:                          22.503   Prob(JB):                         0.00
# Kurtosis:                    4662.576   Cond. No.                         66.4
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Resultados de Regresión en B3':
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                       0.545
# Model:                            OLS   Adj. R-squared:                  0.545
# Method:                 Least Squares   F-statistic:                 2.067e+05
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        07:26:41   Log-Likelihood:            -9.7027e+05
# No. Observations:              172894   AIC:                         1.941e+06
# Df Residuals:                  172892   BIC:                         1.941e+06
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         23.7428      0.180    131.553      0.000      23.389      24.097
# VIVTOT2020     1.5490      0.003    454.697      0.000       1.542       1.556
# ==============================================================================
# Omnibus:                   487157.998   Durbin-Watson:                   1.270
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     657322528400.929
# Skew:                          35.572   Prob(JB):                         0.00
# Kurtosis:                    9554.968   Cond. No.                         60.0
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Resultados de Regresión en B1:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                       0.587
# Model:                            OLS   Adj. R-squared:                  0.587
# Method:                 Least Squares   F-statistic:                 3.790e+04
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):               0.00
# Time:                        07:26:41   Log-Likelihood:            -1.4569e+05
# No. Observations:               26699   AIC:                         2.914e+05
# Df Residuals:                   26697   BIC:                         2.914e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          8.9842      0.449     20.014      0.000       8.104       9.864
# VIVTOT2020     2.8960      0.015    194.684      0.000       2.867       2.925
# ==============================================================================
# Omnibus:                   102122.125   Durbin-Watson:                   1.887
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):     162630796916.488
# Skew:                          88.510   Prob(JB):                         0.00
# Kurtosis:                   12092.629   Cond. No.                         39.1
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
#
# Resultados de Regresión en DH:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             POPTOT2020   R-squared:                         nan
# Model:                            OLS   Adj. R-squared:                    nan
# Method:                 Least Squares   F-statistic:                       nan
# Date:                Wed, 13 Nov 2024   Prob (F-statistic):                nan
# Time:                        07:26:41   Log-Likelihood:                    inf
# No. Observations:               15774   AIC:                              -inf
# Df Residuals:                   15772   BIC:                              -inf
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const               0          0        nan        nan           0           0
# VIVTOT2020          0          0        nan        nan           0           0
# ==============================================================================
# Omnibus:                          nan   Durbin-Watson:                     nan
# Prob(Omnibus):                    nan   Jarque-Bera (JB):                  nan
# Skew:                             nan   Prob(JB):                          nan
# Kurtosis:                         nan   Cond. No.                         15.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# C:\Users\AMIM GTAC\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1783: RuntimeWarning: invalid value encountered in scalar divide
#   return 1 - self.ssr/self.centered_tss
# C:\Users\AMIM GTAC\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:1872: RuntimeWarning: invalid value encountered in scalar divide
#   return self.mse_model/self.mse_resid
# C:\Users\AMIM GTAC\anaconda3\Lib\site-packages\statsmodels\regression\linear_model.py:958: RuntimeWarning: divide by zero encountered in log
#   llf = -nobs2*np.log(2*np.pi) - nobs2*np.log(ssr / nobs) - nobs2
# C:\Users\AMIM GTAC\anaconda3\Lib\site-packages\statsmodels\stats\stattools.py:50: RuntimeWarning: invalid value encountered in scalar divide
#   dw = np.sum(diff_resids**2, axis=axis) / np.sum(resids**2, axis=axis)

# %%
import statsmodels.formula.api as smf

# Modelo ANOVA
modelo_anova = smf.ols('POPTOT2020 ~ TIPOLOGIA + VIVTOT2020', data=MAPA_df).fit()

# Tabla ANOVA
tabla_anova = sm.stats.anova_lm(modelo_anova, typ=2)

# Mostrar resultados
print("Resultados del ANOVA:")
print(tabla_anova)
# Out:
# Resultados del ANOVA:
#                   sum_sq        df             F  PR(>F)
# TIPOLOGIA   5.910304e+07       7.0  3.427692e+03     0.0
# VIVTOT2020  9.643900e+09       1.0  3.915099e+06     0.0
# Residual    2.311214e+09  938275.0           NaN     NaN

# %%
import statsmodels.api as sm
from statsmodels.regression.mixed_linear_model import MixedLM

# Especificar el modelo multinivel (usamos TIPOLOGIA como nivel jerárquico)
# Población es la variable dependiente, Vivienda es la independiente
modelo_ml = MixedLM(MAPA_df['POPTOT2020'], MAPA_df[['VIVTOT2020']], groups=MAPA_df['TIPOLOGIA'])
modelo_ml_fit = modelo_ml.fit()

# Mostrar resumen
print("Resultados del Modelo de Regresión Multinivel:")
print(modelo_ml_fit.summary())
# Out:
# Resultados del Modelo de Regresión Multinivel:
#            Mixed Linear Model Regression Results
# ============================================================
# Model:            MixedLM  Dependent Variable: POPTOT2020
# No. Observations: 938284   Method:             REML
# No. Groups:       8        Scale:              2463.2396
# Min. group size:  15774    Log-Likelihood:     -4995057.1454
# Max. group size:  222489   Converged:          Yes
# Mean group size:  117285.5
# ------------------------------------------------------------
#                Coef.   Std.Err.    z     P>|z| [0.025 0.975]
# ------------------------------------------------------------
# VIVTOT2020       2.423    0.001 1978.674 0.000  2.421  2.426
# Group Var     2463.240
# ============================================================
# C:\Users\AMIM GTAC\anaconda3\Lib\site-packages\statsmodels\regression\mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
